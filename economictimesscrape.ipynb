# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
response=requests.get('https://economictimes.indiatimes.com/')
response.status_code # status code 200 defines Success - OK
# Out:
# 200

# %%
soup=BeautifulSoup(response.content,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><script>(function(){function m(u){var s=u+"=",b=document.cookie.split(";");for(var r=0;r<b.length;r++){var t=b[r];while(t.charAt(0)==" "){t=t.substring(1,t.length)}if(t.indexOf(s)==0){return t.substring(s.length,t.length)}}return null}var l=JSON.parse(localStorage.getItem("jStorage")||"{}")||{},c=l["prime_"+m("TicketId")]||{},q=l.userInfo,g=m("ssoid"),i=c.permissions||[],e=i.indexOf("subscribed")>-1?1:0,k="et_nhp_"+g,d=window.localStorage&&localStorage.getItem(k)||"",h=d.split("-"),n=document.getElementsByTagName("html")[0],p=location.href,o=(p.indexOf("dev8243")!=-1||p.indexOf("stg.")!=-1?0:1),a=new Date().getTime(),j=60*60*1000;
# function f(){window.location.href="/default_prime.cms";if(p.indexOf("fromsrc")!=-1&&p.indexOf("redeemvoucher")!=-1){window.location.href="/default_prime.cms"+window.location.search}}if(e&&q.email&&p.indexOf("dev=1")==-1){f()}})();<!--/defaultp_redirection.cms?minify=1potime:10--></script><link href="//economictimes.indiatimes.com/icons/etfavicon.ico" rel="shortcut icon"/><title>Business News Today: Read Latest Business news, India Business News Live, Share Market &amp; Economy News | The Economic Times</title><meta content="Saturday, February 25, 2023  03:25:00 PM" http-equiv="Last-Modified"/><meta content="Business news today: Read India Business news Live. Latest Business news and updates on Finance, share market, IPO, economy. Discover Business News Headlines, Top Financial News and more on The Economic Times." name="description"/><meta content="business news, india business news, business news today, latest business news, live business news, india business news live" name="keywords"/><link href="/manifest.cms" rel="manifest"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://cm.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://img.etimg.com" rel="preconnect"/><link href="https://js.etimg.com" rel="preconnect"/><link href="https://css.etimg.com" rel="preconnect"/><link href="https://sb.scorecardresearch.com" rel="preconnect"/><link href="https://ade.clmbtech.com" rel="preconnect"/><link href="https://www.googletagservices.com" rel="preconnect"/><link href="https://ads.pubmatic.com" rel="preconnect"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="https://static.clmbtech.com" rel="preconnect"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//connect.facebook.net" rel="dns-prefetch"/><link href="//cm.g.doubleclick.net" rel="dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://img.etimg.com" rel="dns-prefetch"/><link href="https://js.etimg.com" rel="dns-prefetch"/><link href="https://css.etimg.com" rel="dns-prefetch"/><link href="//sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://ade.clmbtech.com" rel="dns-prefetch"/><link href="https://jssocdn.indiatimes.com" rel="dns-prefetch"/><link href="https://jsso.indiatimes.com" rel="dns-prefetch"/><link href="https://static.growthrx.in" rel="dns-prefetch"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/faustina-v6-latin-500.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-500.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-600.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-700.woff2" rel="preload" type="font/woff2"/><script>window.pageLoadStarted = (new Date()).getTime();</script><link as="script" fetchpriority="high" href="https://js.etimg.com/d/js_jquery_cdn/v-1.cms" rel="preload"/><link as="script" fetchpriority="high" href="https://js.etimg.com/d/js_scripts_cdn/v-1.cms" rel="preload"/><link as="script" fetchpriority="high" href="https://js.etimg.com/d/js_common_new/v-533,minify-1.cms" rel="preload"/><meta content="21540067693" property="fb:pages"/><link href="https://economictimes.indiatimes.com/icons/etfavicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://economictimes.indiatimes.com/thumb/width-120,height-120,msid-75267040/et.jpg" rel="apple-touch-icon"/><link href="https://c.amazon-adsy ...
# 	        function errorLogs(data, fallback) { if(data && window.location.search.indexOf('utm_source') == -1) { try { var o = window.location.origin, isLive = (o.indexOf('dev') == -1 && o.indexOf('pwa') == -1 ? 1 : 0), url = data.href || data.src || '', type = (data.localName || data.tagName) + (data.attributes.fallbackfile ? ' fallbackfile': ''), ua = window.navigator && window.navigator.userAgent; var logdata = "logdata=" + JSON.stringify({mode: (isLive ? 'modeLive' : 'modeDev'), channel:'Error_desktop', type:type, data:encodeURIComponent(url), userAgent: ua, url: window.location.href}); var xhr = new XMLHttpRequest(); xhr.withCredentials = true; xhr.open("POST", "https://etx.indiatimes.com/log?et=errorLogs"); xhr.setRequestHeader("Content-Type", "application/x-www-form-urlencoded"); xhr.send(logdata); var fpArr = url.split('.com'), fp = fpArr[1], ft = fp.indexOf('js_') != -1 && 'js' || fp.indexOf('css_') != -1 && 'css'; !fallback && loadAssets(ft, fp); } catch (e) {} } }
#
# 	        function loadAssets(t, f) {
# 	            //f = f + (f.indexOf('?')!=-1?'&':'?')+'ref=fallbackFile'
#                 if (t=="js"){
#                     var fileref=document.createElement('script')
#                     fileref.setAttribute("type","text/javascript")
#                     fileref.setAttribute("src", f)
#                 } else if (t=="css"){
#                     var fileref=document.createElement("link")
#                     fileref.setAttribute("rel", "stylesheet")
#                     fileref.setAttribute("type", "text/css")
#                     fileref.setAttribute("href", f)
#                 }
#                 if (typeof fileref!="undefined"){
#                     fileref.setAttribute("fallbackfile", "1")
#                     fileref.setAttribute("onerror", "errorLogs(this, 1)")
#                     document.getElementsByTagName("head")[0].appendChild(fileref)
#                 }
#             }
#
# 	    </script><link fetchpriority="high" href="https://css.etimg.com/d/et_fonts/v-13,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link fetchpriority="high" href="https://css.etimg.com/d/css_main/v-51,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link as="style" href="https://css.etimg.com/d/css_common_new/v-291,minify-1.cms" onerror="errorLogs(this)" onload="this.rel='stylesheet'" rel="preload" type="text/css"/><noscript><link href="https://css.etimg.com/d/css_common_new/v-291,minify-1.cms" rel="stylesheet"/></noscript><link href="https://css.etimg.com/d/css_default_new2/v-57,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><script>(function() {var lh = location.host; if(lh.indexOf('economictimes.com') == -1 && lh.indexOf('india'+'times'+'.com') == -1 && lh.indexOf('archive'+'.org') == -1 && lh.indexOf('webcache' + '.googleusercontent'+ '.com') == -1) { window.location.href = 'https' + '://' + 'economictimes' + '.indiatimes.'+ 'com' + '?frmref=' + location.host }})()</script><script>
#
# 	        function getCookie(n) {var ne = n + "=", ca = document.cookie.split(';');for (var i=0;i< ca.length;i++){ var c = ca[i]; while (c.charAt(0) == ' ') c = c.substring(1, c.length); if (c.indexOf(ne) == 0) return c.substring(ne.length, c.length); } return null; }
#
#
# 	    var objVc = {env:'live',version_on:'2023.02.25 15:17',vcLScacheTime:'10',js_etsubscription:'2',js_onboarding_popup_sh:'13',js_comments:'111',js_googleslock:'782',js_googlelogin:'69',js_common_buydirect:'752',js_bookmark:'24',js_follow:'12',js_highcharts:'4',js_highcharts3d:'2',js_googlecharts:'1',js_sr_search:'1',js_ask_the_expert_crypto:'16',js_articleshow_main:'229',css_articleshow_new:'111',js_login:'101',js_datepicker:'2',js_push:'61',js_athena_distribution:'30',js_athena_distribution_wap:'27',js_slikeplayernew:'18',js_access_prime_pass:'4',js_prime_access_functions:'4',css_buydirect:'14',css_commoncalc:'29',js_tradenow:'26',interstitial_web:'1',int_countrychk_web:'1',int_allowedcountry_web:'1,2,3,4,5,6',int_fequencycap_web:'4',extended_fcap_hrs_web:'18',js_common_wap:'344',js_common_markets_wap:'11',js_watchlist_wap:'15',js_sr_search_wap:'8',js_ask_the_expert_crypto_wap:'16',js_athenalive_wap:'87',js_commonall:'143',js_bookmark_wap:'13',js_socialdatacapture_min_wap:'46',wap_interstitial_start:'Jun 03, 2021 23:59:00',wap_interstitial_end:'Mar 31, 2023 23:59:00',int_countrychk_wap:'0',int_allowedcountry_wap:'1,2',cpd_wap:'1',lib_login:'/js_feed/jsso_crosswalk_legacy_min.cms',live_tv_skin:'0',global_cube:'0',global_cube_wap:'0',global_cube_faces:'2',global_cube_fullad:'0',global_cube_landingon:'sensex',global_cube_wap_url:'https://m.economictimes.com/iframe_cube.cms',currency_ad_wap:'1',site_sync:'0',ticker_ad:'0',ticker_ad_desktop_only:'0',aff_package:'bnsov',aff_package_wap:'bnsov',ticker_ad_home:'0',adx:'1',logAdsStatus:'0',amazon_bidding:'0',amazon_tam:'1',amazon_tam_web:'0',js_newsltrpopup:'126',nlExpiry:'864000',nlReloadExpiry:'30',js_primetargeting_popup:'9',js_inappmsg:'8',plan_on_paywall:'0',skip_trial:'100',planEntryPointCache:'3',trackAdCode:'0',ajaxError:'1',cTId:'WWW-R7W-Z45Z',oauth:'oauth2',oauthClientId:'b2a8e883ec676f417520f422068a4742',planPage:'/plans.cms',planPageTest:'https://economictimes.indiatimes.com/plans.cms',planPageM:'https://m.economictimes.com/plans.cms',subscriptions:'subscriptions',krypton:'kryptonp',apw:'apw',nlSubscribe:'etsub3',exp_login2plan:'0',js_ratingwidget:'9',js_swg:'4',swg:'1',login_paywall:'Starting @ <strike>Rs150</strike> Rs120/month',singularPlanExp:'0',intro_offer_banner:'0',ctaTxtExp:'50',mf_defaultTab:'1',intro_offer:'0',article_recommendations:'100',primeTargeting:'1',skipnlpopup:'1',skipCryptoPopup:'1',js_article_recommendations:'21',skiparticle_recommendations_rhs:'1',skiparticle_recommendations_in:'1',skipwhatsapp_banner:'1',liveTvLsName:'bandTvCheckPlayed3',liveTvLsValue:'3600',survicate_loyaluser_count:'15',js_etbenefits:'36',js_tponboarding:'3',js_giftstory:'11',disable_MFOP_wap:'1',missedStoryPercent:'30',missedStoryDays:'7',missedStoryMinCount:'3',guestOTPEnabled:'0',paywallSubscriberFlow:'0',js_paywallsubflow:'3',signinwallSubscriberFlow:'50',web_productIntervention:'0111101010',wap_productIntervention:'100101011',mktTopAppDownloader:'1',mktBottomAppDownloader:'1',stocksRecoPopup:'0',paywall_mloffer:'0',onboarding_tpoffer:'1',ml_flag:'0',budget2023_livetv_onOff:'0',budget2023_tv_lBStartTime:'240',budget2023_tv_lBVisibiltyTime:'10',dummy:''};
#         (function(){
#
#             try {var lsd = localStorage.getItem('objVc'), lsdj = lsd && JSON.parse(lsd) || '', vo = objVc.version_on, lv = new Date(vo), sv = lsdj && lsdj.version_on && new Date(lsdj.version_on) || 0, diff = (sv-lv) / 60000;
#                 if(sv && diff >= 0) {objVc = lsdj;}
#                 else {
#                     var now = Date(), vodo = new Date(vo);
#                     objVc.lsTime = vodo > now ? now.toString() : vo; localStorage.setItem('objVc', JSON.stringify(objVc))
#                 }
#                 if(window.location.search.indexOf('skip_popup=1') != -1) { objVc.skipPopup = 1; }
#             } catch(e) {}
#
#         })()
#         </script><iframe height="0" id="__tiluuid_frame" style="display:none" width="0"></iframe><script>
# 		try {
# 		var __tiluuid = localStorage.getItem('__tiluuid');
#         var __tiluuid_expiry_ms = parseInt(localStorage.getItem('__tiluuid_expiry_ms')) || 1607000000410;
#         if (__tiluuid_expiry_ms <= (new Date()).getTime() || localStorage.getItem('__tiluuid') == null) {
#             function receiveMessage(evt) {
#                 if (evt.origin === 'https://tilanalytics.timesinternet.in') {
#                     if (evt.data && evt.data.__tiluuid) {
#                         __tiluuid = evt.data.__tiluuid;
#                         localStorage.setItem('__tiluuid', __tiluuid);
#                         var isValid = /^[0-9A-F]{8}-[0-9A-F]{4}-4[0-9A-F]{3}-[89AB][0-9A-F]{3}-[0-9A-F]{12}-[0-9]+$/i.test(__tiluuid);
#                         if (isValid) {
#                             localStorage.setItem('__tiluuid_expiry_ms', evt.data.__tiluuid_expiry_ms);
# 							try {
# 							 if (ga){ ga('set', {'dimension57': __tiluuid});}
# 						 	}catch(e) {}
#
#                         }
#                         if (evt.data.reset === true && evt.data.__tiluuid_reset_script_path) {
#                             var reset_tiluuid_element = document.createElement("script");
#                             reset_tiluuid_element.setAttribute("src", (evt.data.__tiluuid_reset_script_path));
#                             document.head.appendChild(reset_tiluuid_element);
#                         }
#                     }
#                 }
#             }
#
#             window.addEventListener('message', receiveMessage, false);
#             document.getElementById("__tiluuid_frame").src = 'https://tilanalytics.timesinternet.in/production/frame-2.1.min.html';
#         }
#
#         var _col_uuid;
#         function setColuuid(){for(var o="_col_uuid=",n=decodeURIComponent(document.cookie).split(";"),t=0;t<n.length;t++){for(var u=n[t];" "==u.charAt(0);)u=u.substring(1);0==u.indexOf(o)&&(_col_uuid=u.substring(o.length,u.length))}};
#         setColuuid();
#
#         }catch(e) {}
# 		    </script><!--/tiluuidscript.cmspotime:4--><script id="geo_script" src="https://economictimes.indiatimes.com/geoapiet?cb=et" type="text/javascript"></script><script>
# 		    geolocation = window.geoinfo && window.geoinfo.geolocation || '';
# 			if(window.localStorage && localStorage.getItem('temp_geolocation')) {var geolocation = localStorage.getItem('temp_geolocation');}
# 		    function allowGDPR() {
# 		        var flag = false, ginfo = window.geoinfo || {};
# 		        if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {flag = true;}
# 		        return flag;
# 		    }
# 		    allowGdpr = (function () {
#                 var flag = 0, ginfo = window.geoinfo || {};
#                 // if not EU(5), and (not US(2) if US(2) then not california(CA))
#                 if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {
#                     flag = 1;
#                 }
#                 return flag;
# 		    })()
# 		    </script><!--/geolocationscript.cmspotime:4--><script>
# 		    var urlParams =window.location.search ? window.location.search : "";
#
#
# 		            var ext_param_check=-1==urlParams.indexOf("utm_medium=display_ext"),aff_param_check=-1==urlParams.indexOf("utm_medium=display_aff");aff_param_check||sessionStorage.setItem("aff_campaign","1"),ext_param_check&&aff_param_check&&function(){objVc=window.objVc||{};var e=objVc.int_countrychk_web?parseInt(objVc.int_countrychk_web):1,t=objVc.int_allowedcountry_web;t=t&&t.split?t.split(","):["1"];var i=objVc.int_fequencycap_web?parseInt(objVc.int_fequencycap_web):3,o=(new Date).getHours();"undefined"!=typeof objVc&&0!=objVc.extended_fcap_hrs_web&&o>=objVc.extended_fcap_hrs_web&&(i+=1);var a={setCookieToSpecificTime:function(e,t,i,o){try{var a=".indiatimes.com",n="";if(e&&t&&i&&(n=e+"="+escape(t)+"; expires="+new Date((new Date).toDateString()+" "+i).toUTCString()+"; domain="+a+"; path=/;"),e&&t&&o){var r=new Date;r.setSeconds(r.getSeconds()+o),n=e+"="+(escape(t)+(null==o?"":"; expires="+r.toUTCString())+"; domain="+a+"; path=/;")}document.cookie=n}catch(e){}},init:function(){var e=1==objVc.interstitial_web?1:0;if(-1!=window.location.search.indexOf("ints=0")&&(e=0),e){var t=getCookie("TicketId"),i=a.getOauthJStorage(t),o=i&&i.permissions||[],n=-1==o.indexOf("subscribed")||-1==o.indexOf("etadfree_subscribed")||0==o.length||0,r=getCookie("ssoid")||getCookie("MSCSAuthID");(!r||r&&!n)&&a.loadInterstitial()}},getDeviceType:function(){try{var e=navigator.userAgent;return/(tablet|ipad|playbook|silk)|(android(?!.*mobi))/i.test(e)?"tablet":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Kindle|Silk-Accelerated|(hpw|web)OS|Opera M(obi|ini)/.test(e)?"mobile":"desktop"}catch(e){console.log("getDeviceType:"+e)}},loadInterstitial:function(){try{var o=document.referrer;if(!(o.indexOf("/ad-free/success")>-1||o.indexOf("/ad-free/subscribed"))>-1||localStorage.getItem("devTool")){window.location;var n=navigator&&navigator.userAgent&&navigator.userAgent.toLowerCase()||"",r=-1!=n.indexOf("bot"),c=-1!=n.indexOf("lighthouse"),s=-1!=n.indexOf("insights"),d=-1!=n.indexOf("ptst/");isWebPageTest=-1!=n.indexOf("ptst_x/");var f=getCookie("int_fcapcount")||0,l=getCookie("et_interstitial_active"),g=window.geoinfo&&geoinfo.geolocation||"1",p=t.indexOf(g);if(!("mobile"==a.getDeviceType()||r||c||s||isWebPageTest||d||l||!(f<i)||0!=e&&-1==p)){a.setCookieToSpecificTime("et_interstitial_active","true","",30);var _=parseInt(f)+1;_<=i&&a.setCookieToSpecificTime("int_fcapcount",_,"23:59:59"),window.sessionStorage&&window.sessionStorage.setItem("intsRef",window.location.href);return window.location.replace("/defaultinterstitial.cms"),!1}}}catch(e){window.errorLogs&&errorLogs({href:JSON.stringify(objVc),localName:"interstitial_error",attributes:""},1)}},getOauthJStorage:function(e){try{return jStorageData=window.localStorage&&localStorage.jStorage?JSON.parse(localStorage.jStorage):{},jStorageData["prime_"+e]}catch(e){}}};a.init()}();
#
# 		        </script><!--/interstitialscript.cms?v=18potime:3--><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_monetize/v-163,minify-1.cms" type="text/javascript"></script><script async="async" fetchpriority="low" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script><script type="text/javascript">
# 	        var optParam = '';
# 	        try {
# 	        var urlParams = window.URLSearchParams && new URLSearchParams(window.location.search),
# 	            optParam = urlParams.get && urlParams.get('opt');
# 	        } catch (e) {}
#
# 	        var objSec = {template: 'default', msid:'2160010', isHome:1, secNames: [],secIds:['2147477890']};
#         var tmplName = tpName = 'default',lang = '',nav_sec1,newHookId,subsec1_value,subsec1_common = '0',newHookId2,subsec2_value,subsec2_common = '0',subsec3_common = '0';
#         var objDim = {d52:'nature_of_content',d96:'continuous_paywall_hits',d112:'ml_status',d95:'monthly_article_count',d113:'ml_score',d10:'user_login_status_hit',d54:'content_shelf_life',d98:'daily_paid_article_count',d110:'paywall_signaling',d53:'content_target_audience',d97:'monthly_paid_article_count',d111:'response_source',d12:'tags_meta_keyword',d56:'degree_of_conten',d11:'content_theme_the_primary_tag',d55:'content_tone',d14:'special_coverage',d58:'et_product_item',d13:'article_publish_time',d16:'video_embed',d15:'audio_embed',d59:'show_paywall_final',d117:'video_status',d61:'paywall_probability',d114:'ml_threshold_value',d60:'paywall_score',d115:'adaptive_status',d63:'paid_articles_read',d62:'eligibility_paywall_rule',d65:'bureau_articles_read',d20:'platform',d64:'free_articles_read',d23:'author_id',d67:'loyalty',d66:'article_length',d25:'page_template',d24:'syft_initiate_page',d68:'paywall_hits',d27:'site_sub_section',d26:'site_section',d29:'section_id',d28:'prime_deal_code',d109:'user_region',d70:'us_election_2020',d72:'paywall_experiment',d71:'plan_group_id',d32:'prime_article_read_before_syft',d75:'watchlist_active_status',d34:'content_age',d33:'prime_article_read_before_success',d36:'sign_in_initiation_position',d35:'subscription_method_hit',d37:'user_subscription_status',d1:'et_product',d2:'blocker_type',d3:'user_login_status_session',d4:'agency',d5:'author_name',d6:'cms_content_publishing_type',d7:'content_personalisation_level',d8:'article_publish_date',d9:'sub_section_name',d40:'freeread',d45:'prime_hp_ui_template',d47:'prime_hp_ui_content_b_color',d46:'prime_hp_ui_content_size',d49:'syft_initiate_position',d48:'content_msid',d92:'last_click_source',d50:'signin_initiate_page',d94:'daily_article_count',d93:'internal_source'};var serverTime = '02.25.2023 15:20:01';var WRInitTime=(new Date()).getTime();
#             (function () {if (self !== top) {var e = function (s) {return document.getElementsByTagName(s)}; e("head")[0].innerHTML = '<style>*{display:none;}</style>'; setTimeout(function () {e("body")[0].innerHTML = ''; var hEle = e("html")[0]; hEle.innerHTML = '<a href="' + self.location + '" target="_blank">economictimes.indiatimes.com</a>'; hEle.className = ''; top.location = self.location; }, 0);}})();
#
#         _log = window.console && console.log ? console.log : function () {};
# 		// Creating Elements for IE : HTML 5 and cross domain checks
# 		(function () {
#     		try {
#     		    var elem = ["article", "aside", "figure", "footer", "figcaption", "header", "nav", "section", "time"];
#     		    for(var i=0; i<=elem.length-1; i++) {document.createElement(elem[i])} var hd = 'indiatimes.com', dd = document.domain,intv,intv2,fo; if (dd != hd && dd.indexOf(hd) != -1) {document.domain = hd}
#     		}catch(e){}
# 		})();
# 		var intv,intv2;var fo;
# 		if(subsec1_value == '1715249553' && subsec2_value == '1052732854'){
# 			subsec1_value = newHookId = '1052732854'; // politicsnation
# 		}else if(subsec1_value == '1715249553' && subsec2_value == '1373380680'){
# 			subsec1_value = newHookId = '1373380680'; // Economy
# 		}
#
# 		if(optParam != "1") {
#
#
# 	    customDimension = window.customDimension || {};
# 	    function setDim(dim, val, init) { try { if(dim) { var key = 'dimension' + dim, objDim = {}; objDim[key] = val; customDimension[key] = val; init && ga('set', objDim); } }catch(e){} }
#
#
#                 var _gaq = _gaq || [];
#                 var customDimension = customDimension || {};
#                 var analytics_js_path = 'https://www.google-analytics.com/analytics.js';
#                 (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                 })(window,document,'script',analytics_js_path,'ga');
#                 var gaProperty = 'UA-198011-5';
#                 var disableStr = 'ga-disable';
#                 if (document.cookie.indexOf(disableStr + '=true') > -1) { window[disableStr + '-' + gaProperty] = true; }
#
#                 ga('set', 'anonymizeIp', true);
#                 ga('create', gaProperty, 'auto', {'allowLinker': true});
#                 ga('require', 'linker');
#                 ga('linker:autoLink', ['economictimes.com']);
#                 ga('require', 'displayfeatures');
#                 try {
#                     var et_ua = window.navigator && navigator.userAgent.toLowerCase() || '';
#                     if(et_ua.indexOf('bot') == -1 && et_ua.indexOf('lighthouse') == -1 && et_ua.indexOf('ptst/') == -1 && et_ua.indexOf('speed insights') == -1) {
#                         window.optimizely = window.optimizely || [];
#                         window.optimizely.push("activateUniversalAnalytics");
#                         ga('require', 'GTM-WV452H7');
#                     }
#                 } catch (e) {}
#
#                 (function () {
#                     setDim(25,"default");
#                     setDim(26,"Home");
#                     setDim(27,"Home");
#                     setDim(29,"0");
#                     setDim(48,"2160010");
#                     setDim(30,window._col_uuid);setDim(57,window.__tiluuid);
#
#
#                     if(window.geolocation) {setDim(109, window.geolocation == 1 ? 'IND' : 'INTER');}
#                     var a = window.localStorage && localStorage.getItem('et_syftCounter') || '';
#                     a = a && JSON.parse(a) || {};
#                     if(a.beforeSyft) {setDim(32,a.beforeSyft);}
#                     if(a.afterSyft) {setDim(33,a.afterSyft);}
#                 })()
#
#
#
# 	    var trafficSource = '';
# 	    function getjStorageVal(keyName) { var jString = localStorage.getItem("jStorage"), value = ''; try { if(jString) { var objJstorage = JSON.parse(jString); value = objJstorage[keyName] ? objJstorage[keyName] : ''; } } catch (e) {} return value; }
# 		(function () {
# 		    function addZero(num) {return (num >= 0 && num < 10) ? '0' + num : num;}
# 		    try {
#     		    lastClick = getjStorageVal('etu_last_click');
#                 if(!lastClick) {
#                     lastClick = document.referrer.indexOf('indiatimes.com') == -1 ? 'direct_landing_articleshow' : 'other';
#                 }
#                 var dref = document.referrer, wlh = window.location.href.toLowerCase(), wlp = window.location.pathname;
#                 if(/google|bing|yahoo/ig.test(dref)) {trafficSource = 'organic';}
#                 else if(/facebook|linkedin|instagram|twitter/ig.test(dref) || wlh.indexOf('utm_medium=social') != -1) { trafficSource = 'social';}
#                 else if(wlh.indexOf('utm_medium=email') != -1) {trafficSource = 'newsletter'; }
#                 else if(wlh.indexOf('utm_source=etnotifications') != -1) {trafficSource = 'notifications'; }
#                 else if(getjStorageVal('etu_source')) { trafficSource = getjStorageVal('etu_source');}
#
#                 if(!trafficSource) {
#                     if(wlp == '/' || wlp == '/default.cms') {trafficSource = 'direct'}
#                     else if(wlp.indexOf('articleshow')) {trafficSource = 'organic'}
#                     else {trafficSource = 'other'}
#                 }
#
#                 var dtObject = new Date(), dt = (dtObject.getFullYear() + '' + addZero(dtObject.getMonth() + 1) + '' + addZero(dtObject.getDate())), key = 'et_article_' + dt;
#                 var articleReadCountToday = (getjStorageVal(key) || []).length;
#                 var articleReadCountMonth = 0;
#                 var paidArticleReadCountMonth = 0;
#                 var jString = localStorage.getItem("jStorage");
#                 try {
#                     if(jString) {
#                         var objJstorage = JSON.parse(jString);
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_article_') != -1}).forEach(function (key) { articleReadCountMonth += getjStorageVal(key).length});
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_primearticle_') != -1}).forEach(function (key) { paidArticleReadCountMonth += getjStorageVal(key) || 0});
#                     }
# 	            } catch (e) {}
#
#                 var paidArticleReadCountTodayKey = 'et_primearticle_' + dt;
#                 var paidArticleReadCountToday = getjStorageVal(paidArticleReadCountTodayKey) || 0;
#                 var continuousPaywallList = getjStorageVal('et_continuousPaywalled') || [];
#
#
#                 setDim(92, lastClick);
#                 setDim(93, trafficSource);
#                 setDim(94, articleReadCountToday);
#                 setDim(95, articleReadCountMonth);
#                 setDim(96, continuousPaywallList.length);
#                 setDim(97, paidArticleReadCountMonth);
#                 setDim(98, paidArticleReadCountToday);
#
#                 var subsStatus = '-', d3 = 'NONLOGGEDIN';
#                 var jData = JSON.parse(localStorage.getItem('jStorage'));
#                 var b = document.getElementsByTagName('html')[0];
#                 if(ssoid = getCookie('ssoid')) {
#                     try {
#                         d3 = 'LOGGEDIN';
#                         var grx_userData = jData && jData['prime_'+getCookie('TicketId')] || {};
#                         grx_userData = grx_userData || {};
#                         var grx_up = grx_userData.permissions || [];
#                         if(grx_up.indexOf("expired_subscription") > -1) {
#                             subsStatus = 'Expired User';
#         		        } else if (grx_up.indexOf("subscribed") > -1 && grx_up.indexOf("cancelled_subscription") > -1 && grx_up.indexOf("can_buy_subscription") > -1) {
#         		            subsStatus = 'Paid User - In Trial';
#         		            b.classList.add("cancelled_user");
#         		        } else if(grx_up.indexOf("subscribed") > -1) {
#         		            subsStatus = 'Paid User';
#                             b.classList.add("prime_user");
#         		        } else if(grx_up.indexOf("etadfree_subscribed") > -1) {
#         		            subsStatus = 'Ad Free User';
#         		        } else if (grx_up.length == 0) {
#         		            subsStatus = 'Permission Missing';
#         		        } else {
#         		            subsStatus = 'Free User';
#         		        }
#
#         		        if(grx_up.indexOf("subscribed") > -1) {
#         		            b.classList.add("prime_header");
#         		        }
#     		        } catch (e) {}
#                 } else {
#                     subsStatus = 'Free User';
#                 }
#
#                 if(subsStatus == '-' || subsStatus == '' || subsStatus == 'Expired User' || subsStatus == 'Free User') {
#                     b.classList.add("free_user");
#                 }
#                 setDim(3, d3); setDim(10, d3); setDim(37, subsStatus);
#
# 		    } catch (e) {}
# 		})();
#
#
# 	    setDim(1,'homepage');setDim(24,'homepage');
#
#                 ga('send', 'pageview', customDimension);
#
#
#     		    var newHookId ='0';
#
#         			var subsec1_value ='0', subsec1_2value = '0';
#
#     			        if(subsec1_value == '1715249553' && subsec1_2value == '1052732854'){
#     			            subsec1_value = '1052732854'; // politicsnation
#     			        }else if(subsec1_value == '1715249553' && subsec1_2value == '1373380680'){
#     			            subsec1_value = '1373380680'; // Economy
#     			        }
#
#
#
#         (function (g, r, o, w, t, h, rx) {
#             g[t] = g[t] || function () {(g[t].q = g[t].q || []).push(arguments)
#             }, g[t].l = 1 * new Date();
#             g[t] = g[t] || {}, h = r.createElement(o), rx = r.getElementsByTagName(o)[0];
#             h.async = 1;h.src = w;rx.parentNode.insertBefore(h, rx)
#         })(window, document, 'script', 'https://static.growthrx.in/js/v2/web-sdk.js', 'grx');
#         grx('init', 'gf999c70d');
#         var grxDimension = {url: window.location.href, title : document.title, referral_url : document.referrer, platform: 'desktop'};
#         var pfuuid = getCookie('pfuuid');
#         if(pfuuid) { grxDimension['et_uuid'] = pfuuid}
#
#         grx('config',"service_worker","/et_serviceworker.cms");
#         grx('config',"applicationServerKey","BIEYq99VozBXu5wtCtElr19cYzEZCgSZAYV5amfqzU1IWrR8SWr5T0Htp72bVbslw08rhMJvkrRFT_11HS8zz5c");
#         var isSafari = /^((?!chrome|android).)*safari/i.test(navigator.userAgent);
#         var isPlanPage = "false";
#         var isLoginPage = "false";
#
#         if(isPlanPage === "false" && isLoginPage === "false" && !isSafari) {
#             grx('enableCustompopup');
#         }
#
#
#
#             (function () {
#                 grx('userId', getCookie('ssoid') || '-');
#                 try {
#                     if(window.localStorage && localStorage.getItem) {
#                         var jString = localStorage.getItem("jStorage");
#                         if(jString) {
#                             var objJstorage = JSON.parse(jString), objProf = objJstorage['et_subscription_profile'], userInfo = objJstorage['userInfo'] || {}, peuuid = getCookie('peuuid'), pfuuid = getCookie('pfuuid');
#                             for (var attrname in objProf) { grxDimension[attrname] = objProf[attrname]; };
#                             var dt = new Date(), tDate = dt.getDate()+'-'+(dt.getMonth()+1)+'-'+dt.getFullYear(),loggedIn = (getCookie('ssoid') ? 'Y' : 'N');
#                             grxDimension['first_date_on_et'] = objJstorage['et_first_date'] || tDate;
#                             grxDimension['last_visited_date'] = tDate;
#                             grxDimension['logged_in'] = userInfo['email'] ? 'Y' : 'N';
#                             grxDimension['email'] = userInfo['email'] || '-';
#                             grxDimension['first_name'] = userInfo['fname'] || '-';
#                             grxDimension['last_name'] = userInfo['lname'] || '-';
#                             grxDimension['current_subscriber_status'] = customDimension.dimension37 || '-';
#                             if(peuuid) {grxDimension['web_peuuid'] = peuuid;}
#                             if(pfuuid) {grxDimension['web_pfuuid'] = pfuuid;}
#                         }
#                     }
#                     if(window.customDimension && window.objDim) {
#                         for(key in customDimension) {
#                             var dimId = 'd' + key.substr(9, key.length);
#                             if(objDim[dimId] && typeof customDimension[key] != 'undefined') { grxDimension[objDim[dimId]] = customDimension[key]; }
#                         }
#                     }
#                 }catch(e) {
#                     console.log('Error profile Dimension');
#                 }
#             })()
#
#         grx('track', 'page_view', grxDimension);
#
#             var _comscore = _comscore || [];
#             _comscore.push({ c1: "2", c2: "6036484"});
#
#             if(window.allowGdpr == 1) {
#                 (function() {
#                     var s = document.createElement('script'), el = document.getElementsByTagName("script")[0]; s.async = true;
#                     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#                     el.parentNode.insertBefore(s, el);
#                 })();
#             }
#
#
#
#                 if(window.allowGdpr == 1) {
#                     (function() {
#             			function pingIbeat() {
#                 			window._pg_endpt=(new Date()).getTime();
#                 			var e = document.createElement('script');
#                 			e.setAttribute('language', 'javascript');
#                 			e.setAttribute('type', 'text/javascript');
#                 			e.setAttribute('async', true);
#                 			var dt = window.dateFormat ? dateFormat(new Date(), '%Y%M%d') : 1;
#                 			var sd = window.objDomain && objDomain.js || '';
#                 			e.setAttribute('src', sd + '/js_ibeat_ext.cms?ver=9&v=' + dt);
#                 			if((window.location.href.indexOf('etdev8'))>-1 || (window.location.href.indexOf('etstg'))>-1) {
#                 			    e.setAttribute('src', "https://agi-static.indiatimes.com/cms-common/stg/stg-ibeat.min.js");
#                 			}
#                 			document.head.appendChild(e);
#             			}
#             			if(typeof window.addEventListener == 'function') {
#             			    window.addEventListener("load", pingIbeat, false);
#             			} else {
#                 			var oldonload = window.onload;
#                 			window.onload = (typeof window.onload != 'function') ?
#                 			pingIbeat : function() { oldonload(); pingIbeat(); };
#             			}
#             		})();
#                 }
#
#
#         }
# 	    </script><script type="application/ld+json">
#         	    {
#         	        "@context" : "https://schema.org",
#         		  	"@type": "NewsMediaOrganization",
#         		  	"name": "Economic Times",
#         		    "url" : "https://economictimes.indiatimes.com/","sameAs" : [ "https://www.facebook.com/EconomicTimes","https://twitter.com/economictimes","https://plus.google.com/+TheEconomicTimes"],
#         		    "logo": {
#         		      "@type": "ImageObject",
#             	      "url": "https://img.etimg.com/thumb/msid-76939477,width-600,height-60,quality-100/economictimes.jpg",
#         		      "width": 600,
#         		      "height": 60
#         		    }
#         		  }
#             </script><script>
# 				    var subsec1_value = '';
# 				    var skinningExist=false;
# 				        /*ints = '1', // 0 -> inactive, 1 -> active
# 				        intsCountryChk = 1, // 1 -> if target to specific location, 0 -> no location
# 				        intsAllowedCountry = [1], // please mark ids without quote e.g [2,3,4]
# 				        intsFequencyCap = 3,
# 				        intsPath = '/defaultinterstitial.cms';*/
# 				        // intsPath = '/configspace/etmain_static/content/defaultinterstitial.html';
#
#
#         				function getQueryParams(qs) {
#         			        qs = qs.split('+').join(' ');
#         			        var params = {},
#         			            tokens,
#         			            re = /[?&]?([^=]+)=([^&]*)/g;
#         			        while (tokens = re.exec(qs)) {
#         			            params[decodeURIComponent(tokens[1])] = decodeURIComponent(tokens[2]);
#         			        }
#         			        return params;
#     			        }
#         			    /*var query = getQueryParams(document.location.search);
#
#     				    ints = query.ints ? query.ints : ints;*/
#                      	// var homePageRedirectTo = '/budget';
#
# 				</script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/jshome_topnew/v-58,minify-1.cms" type="text/javascript"></script><style>
#                     .livetv_cont{position:relative;}
#                     .livetv_layer{position:absolute;width: 152px; height: 114px;z-index:1;cursor:pointer;}
#                     .free_user #topStories [data-p='24'] h2 a{font-size: 14px;font-weight:500;}
#                     .free_user #topStories [data-p='24'] img.smallImg{display:none;}
#                     .mainLead{text-align:center;margin:0 0 30px 0}
#                     .mainLead .main a{font-size:32px;color:#000;font-weight: 700;margin-bottom: 10px;font-family:'Faustina',sans-serif;}
#                     .prime_user .iframeyt{display:none;}
#                     .main_container a:visited:not(.skip_vcolor):not(h2 a):not(h4 a):not(.head a):not(.top_mf_wdgt a):not(#sportlight_mf a):not(.moreNews a):not(.Ntxt a), .newsByInd h4 a:visited { color: #636363; }
#                     /*header.header {background-image: url(https://img.etimg.com/photo/94940834.cms);margin: 0 auto;box-sizing: border-box;display: table;width: 1003px;position: relative;padding: 7px 0;z-index: 2;min-height: 110px;background-size:1000px;}*/
#                 </style></head><body><div data-adsslot="ET_Home/ET_Home_Home/ET_HP_Skin_RHS_125" data-loc="All" data-size="[[160, 600], [125, 600],[120,600]]" id="div-gpt-ad-14245244223081-0-oop1" style="position: fixed; top: 0px; left: 0; margin-left: calc((100% - 1003px) / 2 - -1004px);"></div><div class="skinning_left" data-adsslot="ET_Home/ET_Home_Home/ET_HP_Skin_LHS_125" data-fallback="1" data-loc="All" data-size="[[160, 600], [125, 600],[120,600]]" id="skinningleft_backup"></div><div class="no_onetaplogin hidden"></div><main class="pageHolder 268"><div class="primeDW" id="topAd" l1="0" l2="0" l3="0" lan=""><section id="topAd" testpage="0" vw_campaign="0"><div data-adsslot="ET_Home/ET_Home_Home/ET_HP_ATF_728" data-loc="All" data-oop="0" data-size="[[1003, 90],[970,90],[728, 90]]" id="div-gpt-ad-1590585873929-0"></div></section></div><div class="band"><div class="contentwrapper bandCont clearfix"><div class="flipWrapper" style="float: left;"><div class="mkt_indices_band clearfix"><div class="band-items band-item-sm" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">17,465.80</span><span class="per cSprite_b red">-45.45</span></div></div></div></div><div class="band-items band-item-lg" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/gail-india-ltd/stocks/companyid-4845.cms" target="_blank">GAIL</a><span class="num">103.45</span><span class="per cSprite_b green">5.4</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - #WEB - Click - Pro Investing by Aditya Birla Sun Life Mutual Fund - MarketBand#MarketBand - url" href="https://mutualfund.adityabirlacapital.com/campaign/pro-investing?utm_source=economictimes&amp;utm_medium=product_integration&amp;utm_campaign=pro_investing" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="r
=toppotime:2--></div></div></div></header><div class="srch-container prel"><div class="srch-overlay-div" id="topSearch"><div class="srch-overlay-content"><input autocomplete="off" class="inputBox" data-search-input="" name="ticker_newsearch" placeholder="Search News, Stock Quotes &amp; NAV" type="text" value=""/><div class="srch-btn btn">Search</div><div class="srch-close">+</div></div></div></div><div class="navFixRef"></div><div class="nav_block clr" id="topnavBlk"><nav class="level1 contentwrapper" data-ga-category="EThome-TopNav" id="topnav" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement" nav-sec1=""><div class="sections" id="sideMenu"><span class="menuIcon cSprite"></span><nav class="ddNav" id="sideBarNav"></nav></div><div><a class="current" href="/" itemprop="url"><meta content="Home" itemprop="name"/>Home</a></div><div data-ga-action="ETPrime"><a class ...
#                         Read Today's Paper
# ...
#             	                </span></td></tr><tr><td class="stockName"><a href="https://economictimes.indiatimes.com/itc-ltd/stocks/companyid-13554.cms" target="_blank" title="ITC Share Price">ITC Share Price</a></td><td class="stockValue">385.10</td></tr><tr><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-2.50 (-0.64%)
#             	                </span></td></tr><tr><td class="stockName"><a href="https://economictimes.indiatimes.com/adani-power-ltd/stocks/companyid-23479.cms" target="_blank" title="Adani Power Share Price">Adani Power Share Price</a></td><td class="stockValue">146.65</td></tr><tr><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-7.70 (-4.99%)
#             	                </span></td></tr><tr><td class="stockName"><a href="https://economictimes.indiatimes.com/infosys-ltd/stocks/companyid-10960.cms" target="_blank" title="Infosys Share Price">Infosys Share Price</a></td><td class="stockValue">1550.65</td></tr><tr><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="">-0.05 (0.00%)
#             	                </span></td></tr><tr><td class="stockName"><a href="https://economictimes.indiatimes.com/reliance-industries-ltd/stocks/companyid-13215.cms" target="_blank" title="RIL Share Price">RIL Share Price</a></td><td class="stockValue">2383.70</td></tr><tr><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per green">16.20 (0.68%)
#             	                </span></td></tr><tr class="hide moreData"><td class="stockName"><a href="https://economictimes.indiatimes.com/tata-consultancy-services-ltd/stocks/companyid-8345.cms" target="_blank" title="TCS Share Price">TCS Share Price</a></td><td class="stockValue">3400.45</td></tr><tr class="hide moreData"><td class="brdrbt"><span class="dateTimeStock">03:58 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-13.35 (-0.39%)
#             	                </span></td></tr><tr class="hide moreData"><td class="stockName"><a href="https://economictimes.indiatimes.com/tata-steel-ltd/stocks/companyid-12902.cms" target="_blank" title="Tata Steel Share Price">Tata Steel Share Price</a></td><td class="stockValue">109.75</td></tr><tr class="hide moreData"><td class="brdrbt"><span class="dateTimeStock">04:00 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-2.30 (-2.05%)
#             	                </span></td></tr><tr class="hide moreData"><td class="stockName"><a href="https://economictimes.indiatimes.com/yes-bank-ltd/stocks/companyid-16552.cms" target="_blank" title="YES Bank Share Price">YES Bank Share Price</a></td><td class="stockValue">16.15</td></tr><tr class="hide moreData"><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-0.25 (-1.52%)
#             	                </span></td></tr><tr class="hide moreData"><td class="stockName"><a href="https://economictimes.indiatimes.com/hdfc-bank-ltd/stocks/companyid-9195.cms" target="_blank" title="HDFC Bank Share Price">HDFC Bank Share Price</a></td><td class="stockValue">1588.95</td></tr><tr class="hide moreData"><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-14.30 (-0.89%)
#             	                </span></td></tr><tr class="hide moreData"><td class="stockName"><a href="https://economictimes.indiatimes.com/wipro-ltd/stocks/companyid-12799.cms" target="_blank" title="Wipro Share Price">Wipro Share Price</a></td><td class="stockValue">393.30</td></tr><tr class="hide moreData"><td class="brdrbt"><span class="dateTimeStock">03:59 PM | 24 Feb 2023</span></td><td class="stockValue brdrbt"><span class="cSprite_b per red">-0.65 (-0.16%)
#             	                </span></td></tr><tr><td colspan="2"><span class="js_loadMoreStocks">Load more..</span></td></tr></tbody></table></section><!--/most_searched_stocks.cmspotime:13--><div id="politics"><section class="secWidget clearfix" data-ga-action="Widget Politics" data-ga-impression="HP Impression#Widget Politics#url" id="politicsWidget"><h2 class="heading"><a data-ga-onclick="Title - href" href="/news/politics-nation" target="_blank">Politics</a></h2><div class="stories flt"><div class="stryList clearfix"><span data-ga-onclick="1 - href" href="/news/politics-and-nation/my-innings-could-conclude-with-bharat-jodo-yatra-sonia-gandhi-at-congress-plenary-session/articleshow/98230721.cms"><img alt='"My innings could conclude with Bharat Jodo Yatra..." Sonia Gandhi at Congress plenary session' class="lazy flr" data-original="https://img.etimg.com/thumb/width-60,height-45,imgsize-1046864,msid-98230721,quality-100/my-innings-could-conclude-with-bharat-jodo-yatra-sonia-gandhi-at-congress-plenary-session.jpg" height="45" src="https://img.etimg.com/photo/42031747.cms" width="60"/></span><a data-ga-onclick="1 - href" href="/news/politics-and-nation/my-innings-could-conclude-with-bharat-jodo-yatra-sonia-gandhi-at-congress-plenary-session/articleshow/98230721.cms" target="_blank">"My innings could conclude with Bharat Jodo Yatra..." Sonia Gandhi at Congress plenary session</a></div><div class="stryList clearfix"><span data-ga-onclick="2 - href" href="/news/politics-and-nation/bjp-fuelling-fire-of-hatred-targeting-minorities-dalits-tribals-women-congress-leader-sonia-gandhi/articleshow/98229846.cms"><img alt="BJP fuelling fire of hatred, targeting minorities, Dalits, tribals, women: Congress leader Sonia Gandhi" class="lazy flr" data-original="https://img.etimg.com/thumb/width-60,height-45,imgsize-64548,msid-98229846,quality-100/bjp-fuelling-fire-of-hatred-targeting-minorities-dalits-tribals-women-congress-leader-sonia-gandhi.jpg" height="45" src="https://img.etimg.com/photo/42031747.cms" width="60"/></span><a data-ga-onclick="2 - href" href="/news/politics-and-nation/bjp-fuelling-fire-of-hatred-targeting-minorities-dalits-tribals-women-congress-leader-sonia-gandhi/articleshow/98229846.cms" target="_blank">BJP fuelling fire of hatred, targeting minorities, Dalits, tribals, women: Congress leader Sonia Gandhi</a></div><div class="stryList clearfix"><a data-ga-onclick="3 - href" href="/news/politics-and-nation/congress-to-provide-50-pc-reservation-to-scs-sts-obcs-minorities-women-youngsters-in-cwc/articleshow/98229653.cms" target="_blank">Congress to provide 50 pc reservation to SCs, STs, OBCs, minorities, women, youngsters in CWC</a></div><div class="stryList clearfix"><a data-ga-onclick="4 - href" href="/news/politics-and-nation/rs-1000-monthly-assistance-for-women-to-be-implemented-says-tn-cm/articleshow/98229619.cms" target="_blank">Rs 1,000 monthly assistance for women to be implemented, says TN CM</a></div><div class="stryList clearfix"><a data-ga-onclick="5 - href" href="/news/politics-and-nation/apne-baap-ka-samman-nahi-kar-paye-ho-yogi-lashes-out-at-akhilesh-in-up-assembly/articleshow/98228420.cms" target="_blank">"Apne baap ka samman nahi kar paye ho": Yogi Adityanath lashes out at Akhilesh in UP Assembly</a></div></div><div class="clr"></div><div class="moreNews flr"><a data-ga-onclick="More - href" href="/news/politics-nation" target="_blank">Politics</a> »</div></section><!--/home_otherwidget.cms?msid=1052732854&widget=politics&head=Politics&sidestry=true&link=/news/politics-nation&imageStry=2&noOfStry=5potime:37--></div><section class="clearfix"><div class="seoWidget" data-ga-action="Top Trending Terms Seo Widget" id="seoWrapper_rhs"><div class="prel"><div class="head">Top Trending Terms: </div><div class="nextprev-btn slider_embd"><div class="prev-btn arw_blk disable flt" data-ga-onclick="Previous | href"><span class="alft"></span></div><div class="ts-dots flt"><ul></ul></div><div class="next-btn arw_blk ryt flt" ...
#
#     		            if(typeof sessionStorage != 'undefined') {
#                             if(sessionStorage.getItem('stk_ftr_ad_rm')){
#                                 _log("stk_ftr_ad removed");
#                                 document.querySelectorAll(".stk_ftr_ad")[0].remove();
#                             }
#                             if(sessionStorage.getItem('stk_ftr_ad_exin_rm')){
#                                 _log("stk_ftr_ad_exin removed");
#                                 document.querySelectorAll(".stk_ftr_ad_exin")[0].remove();
#                             }
#                         }
#
# 		        </script><span class="hidden livetv_popup"></span><script src="https://js.etimg.com/d/js_jquery_cdn/v-1.cms" type="text/javascript"></script><script src="https://js.etimg.com/d/js_scripts_cdn/v-1.cms" type="text/javascript"></script><script>var language = '';</script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_common_new/v-533,minify-1.cms" type="text/javascript"></script><script defer="" onerror="errorLogs(this)" src="https://js.etimg.com/d/js_etidentifierv/v-23,minify-1.cms" type="text/javascript"></script><script defer="" onerror="errorLogs(this)" src="https://js.etimg.com/d/js_socialdatacapture_min/v-131,minify-1.cms" type="text/javascript"></script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_default_new2/v-72,minify-1.cms" type="text/javascript"></script><script>
#
# 				    var logAPIResponse = 1;
# 				$(document).ready(function () {
#                     var artCnt = customDimension.dimension94;
#                     if(objGdpr.allow() && artCnt && artCnt >= 3) {
#                         loadModule({'module_name': 'js_recommendation', v: 83, ref:'hpRecommendation'});
#                     }
#                     window.loadScript && loadScript('https://sf-objects-s3.tilc.in/sf-objects/cdnperf.js');
#                     var $jS = $.jStorage; if($jS.get('c_oneTapLogin') && $jS.getTTL('c_oneTapLogin') == 0) {$jS.deleteKey('c_oneTapLogin')}
#                 })
#
#                 </script><script>
# 	         if($('.main_container').length == 0) {
# 	            saveLogs({'type': 'main_container', 'container': 'missing'});
# 	            $('#pageContent,#sideBar').wrapAll('<div class="main_container"></div>');
# 	         }
#
# 	    </script><div data-adsslot="ET_ROS_NW/ET_ROS_Andbeyond_1x1" data-loc="All" data-size="[1, 1]" id="div-gpt-ad-1559650249467-0"></div><script type="text/javascript">
# 	    if(optParam != "1") {
#
# 	    try {
# 	        var _page_config;
# 	        var monthName = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'];
#             var IBDate = new Date();
#             var IBDateFmt = function() {
#                 return monthName[IBDate.getMonth()] +' '+IBDate.getDate()+', '+IBDate.getFullYear()+', 12.00 AM IST';
#             }
#             var ibeatDate = ''+ IBDateFmt() +'';
#             var _iBeat_cat = 'Home Page', _iBeat_subcat = '', _iBeat_catids = '2147477890,2160010';
#
#             _page_config = {
#                 host : 'economictimes.indiatimes.com',
#     			key : 'f66e70a45a565c9c76a526c5e9e99df',
#     			domain : 'economictimes.indiatimes.com',
#     			channel :  '',
#     			action : 1,
#     			articleId : 2160010,
#     			contentType: 20,
#             	location : 1,
#             	cat : 'Home Page',
#     			subcat : '',
#     			contenttag : '',
#     			catIds : '2147477890,2160010',
#     			articledt : ibeatDate,
#     			author : '',
#     			url : window.location.href,
#     			iBeatField : 'undefined'
#             }
#
#
#             var _ib_vct = 0;
#             if(ssoid = getCookie('ssoid')) {
#                 try {
#                     _ib_vct = 2;
#                     var jData = JSON.parse(localStorage.getItem('jStorage')),userData = jData && jData['prime_'+getCookie('TicketId')] || {}, up = userData.permissions || [];
#                     if(up.indexOf("subscribed") > -1) {
#     		            _ib_vct = 1;
#     		        } if (grx_up.length == 0) {
#     		            _ib_vct = 0;
#     		        }
# 		        } catch (e) {}
#             } else {
#                 _ib_vct = 3;
#             }
#
#             var _ibeat_track = {"visitor_cat" : _ib_vct}
#
#         } catch (e) {console.error('error', e);}
#
#
# 	    var secname="Home Page";
# 	   var agename='';
#
#
#
# 	    var _mfq = (_mfq || []), mouseflowPath = '/';
#
#
# 	    }
#
# 	    window.setColuuid && setColuuid();
# 	    window.ga && ga('set', {'dimension57': window.__tiluuid, 'dimension30': window._col_uuid});
#
# 	    </script><script>
#                      function invokeLogin(){
# 						try{
# 						isLoggedSso = getCookievaluetwitt('MSCSAuth');
# 						if(Get_Ckie('autologin')!=null){
# 							Delete_Ckie("autologin","/",".indiatimes.com");
# 						}
# 						tpbar1();
# 						}
# 						catch(ex)
# 						{
# 						}
# 						ga('send', 'event', 'Temp', 'invokeLogin', window.location.href);
# 					}
#
# 				</script><script type="text/javascript">
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push
# %%
page_title = soup.title.text

# %%
page_title
# Out:
# 'Business News Today: Read Latest Business news, India Business News Live, Share Market & Economy News | The Economic Times'

# %%
# Extract body of page
page_body = soup.body

# %%
page_body
# Out:
# <body><div data-adsslot="ET_Home/ET_Home_Home/ET_HP_Skin_RHS_125" data-loc="All" data-size="[[160, 600], [125, 600],[120,600]]" id="div-gpt-ad-14245244223081-0-oop1" style="position: fixed; top: 0px; left: 0; margin-left: calc((100% - 1003px) / 2 - -1004px);"></div><div class="skinning_left" data-adsslot="ET_Home/ET_Home_Home/ET_HP_Skin_LHS_125" data-fallback="1" data-loc="All" data-size="[[160, 600], [125, 600],[120,600]]" id="skinningleft_backup"></div><div class="no_onetaplogin hidden"></div><main class="pageHolder 268"><div class="primeDW" id="topAd" l1="0" l2="0" l3="0" lan=""><section id="topAd" testpage="0" vw_campaign="0"><div data-adsslot="ET_Home/ET_Home_Home/ET_HP_ATF_728" data-loc="All" data-oop="0" data-size="[[1003, 90],[970,90],[728, 90]]" id="div-gpt-ad-1590585873929-0"></div></section></div><div class="band"><div class="contentwrapper bandCont clearfix"><div class="flipWrapper" style="float: left;"><div class="mkt_indices_band clearfix"><div class="band-items band-item-sm" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">Nifty</a><span class="num">17,465.80</span><span class="per cSprite_b red">-45.45</span></div></div></div></div><div class="band-items band-item-lg" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/gail-india-ltd/stocks/companyid-4845.cms" target="_blank">GAIL</a><span class="num">103.45</span><span class="per cSprite_b green">5.4</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - #WEB - Click - Pro Investing by Aditya Birla Sun Life Mutual Fund - MarketBand#MarketBand - url" href="https://mutualfund.adityabirlacapital.com/campaign/pro-investing?utm_source=economictimes&amp;utm_medium=product_integration&amp;utm_campaign=pro_investing" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating"></span><span class="ratingGrey"></span></div></div><div class="title" style="font-size:11px;max-width:205px;margin-bottom:4px;" title="Pro Investing by Aditya Birla Sun Life Mutual Fund">Pro Investing by Aditya Birla Sun Life Mutual Fund</div></div><div class="band-content-right flt" style="margin:9px 8px;"><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - ETMarketBand#WEB - Click - Canara Robeco Equity Hybrid Fund Direct-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.canararobeco.com/smart-invest/sign-in?utm_source=ET&amp;utm_medium=InvestNowButton&amp;utm_campaign=EquityHybridFund" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★</span><span class="ratingGrey">★</span></div></div><div class="title" title="Canara Robeco Equity Hybrid Fund Direct-Growth">Canara Robeco Equity Hybrid Fund Direct-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">12.23 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - ETMarketBand#WEB - Click - ICICI Prudential Midcap Fund-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.icicipruamc.com/mutual-fund/equity-funds/icici-prudential-midcap-fund?utm_source=economictimes&amp;utm_medium=investnow&amp;utm_campaign=midcap" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="ICICI Prudential Midcap Fund-Growth">ICICI Prudential Midcap Fund-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">9.29 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div></div></div><div class="band-items grey"><div class="stats_btn"><a class="mktWatch" href="/marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div></div></div></div><!--/market_topband_new.cms?default_tv=0&visualrevenue=HP&tracking=ETHome-IndicesBand&default_tv_popup=0&band_ad_active=0&keepadfirst=1potime:3--><header class="header clearfix default"><div class="dtc vam logoPart tac"><a class="hp_logo" href="/" title="The Economic Times"><img alt="The Economic Times" fetchpriority="fetchpriority" height="51" src="data:image/png;base64,..." width="464"/></a><div class="timeEdition tac"><div class="dib prel edition"><span>English Edition</span><span class="edMenu"><span class="ed">English Edition</span><a class="edHin" data-ga-onclick="Web Top Nav Edition#Hindi#url" href="https://hindi.economictimes.com/" rel="noopener dofollow" target="_blank">हिन्दी</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#gujarati#url" href="https://gujarati.economictimes.com/" rel="noopener dofollow" target="_blank">ગુજરાતી</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#marathi#url" href="https://marathi.economictimes.com/" rel="noopener dofollow" target="_blank">मराठी</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#bengali#url" href="https://bengali.economictimes.com/" rel="noopener dofollow" target="_blank">বাংলা</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#kannada#url" href="https://kannada.economictimes.com/" rel="noopener dofollow" target="_blank">ಕನ್ನಡ</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#malayalam#url" href="https://malayalam.economictimes.com/" rel="noopener dofollow" target="_blank">മലയാളം</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#tamil#url" href="https://tamil.economictimes.com/" rel="noopener dofollow" target="_blank">தமிழ்</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#telugu#url" href="https://telugu.economictimes.com/" rel="noopener dofollow" target="_blank">తెలుగు</a></span></div><span data-dt="2023-02-25 15:25:01.105"><span> | </span><span class="dib time">25 February, 2023, 03:25 PM IST</span></span><span> | </span><a class="dib epaper" data-ga-onclick="Web Top Nav Epaper link#Click on Epaper link#url" href="/printhome.cms" rel="nofollow" target="_blank">Today's Paper</a></div><div class="flr subSign"><a class="dib subScribe" data-ga-onclick="Subscription Flow#SYFT#ATF - url" href="/plans.cms">Subscribe</a><div class="dib signInOut prel signIn"><a class="signInLink" data-ga-onclick="ET Login#Signin - Sign In - Click#ATF - url" href="javascript:objUser.login()">Sign In</a></div><div class="soWrapper"><a class="hdr_spcl_ofr top_f_us" data-ga-onclick="Subscription Flow#SYFT#HomepageOfferHeader" data-url="https://economictimes.indiatimes.com/plans.cms"><prime_campaign>Special Offer on ETPrime</prime_campaign></a><!--/prime_campaign.cms?msid=81429572&bannertype=toppotime:2--></div></div></div></header><div class="srch-container prel"><div class="srch-overlay-div" id="topSearch"><div class="srch-overlay-content"><input autocomplete="off" class="inputBox" data-search-input="" name="ticker_newsearch" placeholder="Search News, Stock Quotes &amp; NAV" type="text" value=""/><div class="srch-btn btn">Search</div><div class="srch-close">+</div></div></div></div><div class="navFixRef"></div><div class="nav_block clr" id="topnavBlk"><nav class="level1 contentwrapper" data-ga-category="EThome-TopNav" id="topnav" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement" nav-sec1=""><div class="sections" id="sideMenu"><span class="menuIcon cSprite"></span><nav class="ddNav" id="sideBarNav"></nav></div><div><a class="current" href="/" itemprop="url"><meta content="Home" itemprop="name"/>Home</a></div><div data-ga-action="ETPrime"><a class ...
#                         Read Today's Paper
# 		            </a></div></div></div><!--/printedition_discoverybanner.cms?tmp=defaultpotime:2--><div class="subheader_wrapper hide"><div class="header_wrapper"><div class="flt"><h5>Read. Lead. Succeed. ET Prime - For Members Only</h5><ul><li>Sharp Insight-rich, Indepth stories across 20+ sectors</li><li>Access the exclusive Economic Times stories, Editorial and Expert opinion</li></ul></div><div class="flr btn_wrapper"><a class="btn uc" data-ga-onclick="Subscription Flow#SYFT#Prime Home Header" id="pricePlan">START YOUR MEMBERSHIP</a></div></div></div><!--/primehome_header.cmspotime:3--><div id="emeritusHeader"></div><div class="clr"></div><style>
# 	        #wa_banner{padding: 12px 61px 7px 13px;box-shadow: 0 4px 6px 0 rgba(0, 0, 0, 0.1);background-image: linear-gradient(to left, #fee9e2 0%, rgba(255, 255, 255, 0.5)), linear-gradient(to bottom, #fff, #fff);}
# 	        #wa_banner > div{display:inline-block;vertical-align:middle}
# 	        #wa_banner h3{font-size:18px}
# 	        #wa_banner p{font-weight:500;line-height:1.25;margin-top: 2px;}
# 	        #wa_banner .subsBtn{padding: 8px 28px 8px 30px;border-radius: 2px;background-color: #e81e3d;font-weight:700;font-size:13px;margin-top: 5px;}
# 	        #wa_banner .subsBtn a{color:#FFF;text-decoration: none;}
# 	    </style><div class="hide" id="wa_banner"><div><img height="41" src="/photo/90287383.cms" style="margin-right:15px" width="40"/></div><div><h3>Be the first one to get exclusive stories!</h3><p>Get only relevant updates on WhatsApp. No Spam.</p></div><div class="subsBtn uc flr"><a data-ga-onclick="WhatsApp_Engagement#Web#banner_click" href="/whatsappalert.cms">Join Us On WhatsApp</a></div></div><!--/home_whatsappbanner.cms?pagetype=defaultpotime:2--><style>
# 	        #stk_bnr,#TP_bnr {width:100%;box-shadow: 0 4px 6px 0 rgba(0, 0, 0, 0.1);text-align: center;}
# 	        #stk_bnr > a,#TP_bnr > a{display:block;cursor: pointer;text-decoration: none;}
# 	        #stk_bnr .bnr_wrapper,#TP_bnr .bnr_wrapper{padding: 12px;font-family: Montserrat;display: flex;align-items: center;width:1003px;margin:0 auto;box-sizing:border-box}
# 	        #TP_bnr .bnr_wrapper{padding: 12px 10px}
# 	        #stk_bnr .dtls{width:75%}
# 	        #TP_bnr .dtls{width:75%}
# 	        #stk_bnr .dtls .dtls_head span,#TP_bnr .dtls .dtls_head span{border-radius: 3px 0 0 3px;background-image: linear-gradient(to bottom, #f54070, #e81e3d);font-size:12px;font-weight:bold;padding: 2px 12px 3px 9px;color: #fff;position: relative;}
# 	        #TP_bnr .dtls .dtls_head span{font-size:9.6px;padding: 4px 12px 3px 7px;}
# 	        #stk_bnr .dtls .dtls_head span:after,#TP_bnr .dtls .dtls_head span:after{content: "";position: absolute;right: 0px;bottom: 0;width: 0px;height: 0px;border-bottom: 10px solid #fff;border-top: 10px solid #fff;border-left: 10px solid transparent;}
# 	        #TP_bnr .dtls .dtls_head span:after{border-bottom: 9px solid #fff;border-top: 9px solid #fff;border-left: 9px solid transparent;}
# 	        #stk_bnr .dtls .dtls_head h2,#TP_bnr .dtls .dtls_head h2{font-family: Faustina;font-size: 24px;font-weight: 600;display: inline;vertical-align: middle;line-height: 23px;margin-left: 8px;}
# 	        #TP_bnr .dtls .dtls_head h2{font-family: Faustina;font-size: 24px;font-weight: 600;display: inline;margin-left: 8px;}
# 	        #stk_bnr .dtls .dtls_bullets,#TP_bnr .dtls .dtls_bullets{margin-top: 6px;}
# 	        #stk_bnr .dtls .dtls_bullets li,#TP_bnr .dtls .dtls_bullets li {font-size: 14px;font-weight: 400;line-height: 1.25;display: inline-block;margin-right: 20px;list-style: none;}
# 	        #TP_bnr .dtls .dtls_bullets li{margin-right: 27px}
# 	        #stk_bnr .dtls .dtls_bullets li:last-child,#TP_bnr .dtls .dtls_bullets li:last-child {margin-right: 0;}
# 	        #stk_bnr .dtls .dtls_bullets li:before,#TP_bnr .dtls .dtls_bullets li:before {width: 2px;display: inline-block;vertical-align: middle;margin: 0 5px 2px 0;}
# 	        #stk_bnr .stock_page_btn,#TP_bnr .stock_page_btn{color: #da2337;font-size:14px;font-weight:600;padding: 8px 14px;display: block;border-radius: 2px;border: solid 1px #da2337;text-align: left;}
# 	        #TP_bnr .stock_page_btn{padding: 8px 12px;}
# 	        .dtls_head h2 img{margin: 0 2px 1px 5px;vertical-align: sub;}
#
# 	        #stk_bnr a:hover .stock_page_btn, #TP_bnr a:hover .stock_page_btn{background-color:#da2337;color:#FFF}
# 	    </style><div class="hide" id="stk_bnr"><a data-ga-onclick="ePaper_discovery#Homepage_Band_Paid_User#HomePage Print Ediion Header" href="/print_edition.cms" target="_blank"><div class="bnr_wrapper"><div class="dtls"><div class="dtls_head"><h2>Introducing <img alt="Print Edition" class="lazy" data-original="https://img.etimg.com/photo/91621060.cms" height="28" src="https://img.etimg.com/photo/42031747.cms" width="175"/> Exclusively For Prime Members</h2></div><div class="dtls_bullets"><li>Experience your Economic Times newspaper, the digital way.</li></div></div><div class="stock_page_btn">Read Today's Print Edition</div></div></a></div><div class="hide" id="TP_bnr"><a class="bnr_click" href="/print_edition.cms" target="_blank"><div class="bnr_wrapper"><div class="dtls"><div class="dtls_head"><h2>Introducing <img alt="Print Edition" class="lazy" data-original="https://img.etimg.com/photo/91621060.cms" height="28" src="https://img.etimg.com/photo/42031747.cms" width="175"/> Exclusively For Prime Members</h2></div><div class="dtls_bullets"><li>Experience your Economic Times newspaper, the digital way.</li></div></div><div class="stock_page_btn">Read Today's Print Edition</div></div></a></div><!--/home_stockbanner.cms?pagetype=defaultpotime:6--><div class="clr"></div><section class="clearfix main_container" data-ga-category="HP Clicks"><section id="pageContent"><section class="latestStry clearfix"><div class="topStories lftBlk flt" data-ga-action="Top Stories" id="topStories" itemscope="itemscope" itemtype="https://schema.org/ItemList"><ul class="newsList flt w-100"><li class="clearfix font_faus" itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><h1><meta content="1" itemprop="position"/><span data-ga-onclick="1 - href" href="/jobs/mid-career/ev-industry-in-india-battles-high-attrition-amid-demand-for-talent/articleshow/98218408.cms" itemprop="url" target="_blank"><meta content="Talent wars are threatening to upend India's electric ride" itemprop="name"/><img alt="Talent wars are threatening to upend India's electric ride" class="latestTopstry flt" height="75" src="https://img.etimg.com/thumb/msid-98218408,width-120,imgsize-10426,resizemode-4/talent-wars-are-threatening-to-upend-indias-electric-ride.jpg" width="100"/></span><a data-ga-onclick="1 - href" href="/jobs/mid-career/ev-industry-in-india-battles-high-attrition-amid-demand-for-talent/articleshow/98218408.cms" itemprop="url" target="_blank">Talent wars are threatening to upend India's electric ride</a></h1></li><li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><meta content="2" itemprop="position"/><span data-ga-onclick="2 - href" href="/news/economy/indicators/extreme-heat-is-coming-know-the-different-ways-it-can-harm-indias-economy/articleshow/98229841.cms" itemprop="url" target="_blank"><meta content="Extreme heat and the risks it poses for India" itemprop="name"/></span><a data-ga-onclick="2 - href" href="/news/economy/indicators/extreme-heat-is-coming-know-the-different-ways-it-can-harm-indias-economy/articleshow/98229841.cms" itemprop="url" target="_blank">Extreme heat and the risks it poses for India</a></li><li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><meta content="3" itemprop="position"/><span data-ga-onclick="3 - href" href="/markets/stocks/news/fears-of-loss-in-adani-group-portfolio-sends-lic-near-all-time-low/articleshow/98226128.cms" itemprop="url" target="_blank"><meta content="Adani fears send LIC near all-time low" itemprop="name"/></span><a data-ga-onclick="3 - href" href="/markets/stocks/news/fears-of-loss-in-adani-group-portfolio-sends-lic-near-all-time-low/articleshow/98226128.cms" itemprop="url" target="_blank">Adani fears send LIC near all-time low</a></li><li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><meta content="4" itemprop="position"/><span data-ga-onclick="4 - href" href= ...
#                     </span></div><div class="wcol"><a class="wrapLines l1" href="/markets/cryptocurrency/ethereum-price/cryptodetail/symbol-eth.cms" onclick="ga('send', 'event', 'HP Data Band', 'eth - click', '')" target="_blank">Ethereum Price</a><span class="fw_600">₹ 1,33,078</span><span class="down"><i class="crypto_sprite1"></i>-2.73%
#                     </span></div><div class="wcol"><a class="wrapLines l1" href="/markets/cryptocurrency/tether-price/cryptodetail/symbol-usdt.cms" onclick="ga('send', 'event', 'HP Data Band', 'usdt - click', '')" target="_blank">Tether Price</a><span class="fw_600">₹ 83.07</span><span class="up"><i class="crypto_sprite1"></i>0.39%
#                     </span></div><div class="wcol"><a class="wrapLines l1" href="/markets/cryptocurrency/bnb-price/cryptodetail/symbol-bnb.cms" onclick="ga('send', 'event', 'HP Data Band', 'bnb - click', '')" target="_blank">BNB Price</a><span class="fw_600">₹ 25,000</span><span class="down"><i class="crypto_sprite1"></i>-2.95%
#                     </span></div></div><div class="moreNews flr"><a data-ga-onclick="More - href" href="/markets/cryptocurrency" target="_blank">Cryptocurrency</a> »</div><!--/home_cryptocurrency_news.cms?msid=82519373potime:7--></section><div class="currencyConverter clearfix"><a href="/markets/forex/currency-converter" target="_blank"><span class="converterImg hpSprite flt"></span></a><form action="/currency_converter.cms" class="flr" method="get" name="forexConverter" onsubmit="return objHome.validateConverter();"><div class="boldText">Rs</div><div class="currency"><input id="amount" name="amount" type="text" value="100"/></div><div class="boldText">To</div><div class="convert"><select class="textboxsubsN" id="tocur" name="tocur"><option selected="true" value="USD">US Dollar</option><option value="CAD">CAN Dollar</option><option value="CNY">Chinese Yuan</option><option value="EUR">Euro</option><option value="HKD">HK Dollar</option><option value="IDR">Indonesian Rupiah</option><option value="JPY">Japanese Yen</option><option value="KRW">Korean Won</option><option value="KWD">Kuwaiti Dinar</option><option value="MYR">Malaysian Ringgit</option><option value="RUB">Russian Rouble</option><option value="SGD">Sing Dollar</option><option value="CHF">Swiss Franc</option><option value="AED">UAE Dirham</option><option value="GBP">UK Pound</option><option onclick="validatefx()" value="">More Currency</option></select><input class="con" data-track="CTA" type="submit" value="Convert"/><input id="fromcur" name="fromcur" type="hidden" value="INR"/></div></form></div><div class="clearfix"><div class="seoWidget" data-ga-action="Markets Seo Widget" id="seoWrapper_markets"><div class="prel"><div class="head"><a data-ga-onclick="Seo - Title - href" href="https://economictimes.indiatimes.com/markets" target="_blank">Markets: </a></div><div class="nextprev-btn slider_embd"><div class="prev-btn arw_blk disable flt" data-ga-onclick="Previous | href"><span class="alft"></span></div><div class="ts-dots flt"><ul></ul></div><div class="next-btn arw_blk ryt flt" data-ga-onclick="Next | href"><span class="aryt"></span></div></div></div><div class="dataWidget overh" id="seoWrapper_Slider_markets"><ul><li><a data-ga-onclick="Seo - 1 - href" href="/markets/stocks/live-blog/bse-sensex-today-live-nifty-stock-market-updates-24-february-2023/liveblog/98193672.cms" target="_blank">Sensex Today</a><a data-ga-onclick="Seo - 2 - href" href="/markets/expert-view/not-comfortable-with-high-leverage-of-adani-stocks-and-never-bought-any-daljeet-singh-kohli/articleshow/97967245.cms" target="_blank">Adani Stocks</a><a data-ga-onclick="Seo - 3 - href" href="/markets/commodities/views/daily-use-ncdex-commodity-headed-lower/articleshow/97364006.cms" target="_blank">NCDEX Commodity</a><a data-ga-onclick="Seo - 4 - href" href="/markets/stocks/news/stocks-to-buy-today-4-short-term-trading-ideas-by-experts-for-27-january-2023/articleshow/97363863.cms" target="_blank">Stocks To Buy Today</a></li><li><a data-ga-onclick="Seo - 5 - href" href="/markets/hang-seng-index" target="_blank">Hang Seng</a><a data-ga-onclick="Seo - 6 - href" href="/markets/dow-jones" target="_blank">Dow Jones</a><a data-ga-onclick="Seo - 7 - href" href="/markets/kospi" target="_blank">Kospi</a><a data-ga-onclick="Seo - 8 - href" href="/markets/ipo" target="_blank">IPO</a></li><li><a data-ga-onclick="Seo - 9 - href" href="/markets/cryptocurrency" target="_blank">Crypto Price</a><a data-ga-onclick="Seo - 10 - href" href="/markets/forex" target="_blank">Forex</a></li></ul></div></div><!--/home_seowidget_new.cms?msid=64647995&layout=new&wname=marketspotime:4--></div><section class="clearfix"><div class="nriHome elediv datalay Edition_home" data-ga-action="nri Discovery" data-impression-ga="nri#discovery - Impression #url" data-layout="nri"><div class="headDiv"><div class="flt"><img alt="NRI" height="42" src="https://img.etimg.com/photo/89824128.cms" width="42"/></div><div class="flt Ntxt"><a data-ga-onclick="Top ...
#             /* Amazon Widget */
#             .amazon_widget ul.categList{white-space: nowrap;}
#             .amazon_widget ul.categList li{width: 149px;position: relative;text-align: center;padding-right: 14px;list-style:none;white-space: normal;display:inline-block;vertical-align: top;}
#             .amazon_widget ul.categList li a{display:block}
#             .amazon_widget ul.categList li a:hover{text-decoration:none}
#             .amazon_widget .categList figure{height:115px;margin:0 auto;border:1px solid #e4e4e4;position:relative}
#             .amazon_widget ul.categList li:hover figure{box-shadow: 0 4px 10px 0 rgba(0, 0, 0, 0.1);}
#             .amazon_widget .categList figure > img {width: auto;height: auto;position: absolute;top: 0;left: 0;bottom: 0;right: 0;max-width: 100%;max-height: 100%;display: block;margin: 0px auto;}
#             .amazon_widget .categList .deal{font-size:10px;padding: 0 4px 0 5px;box-shadow: 0 1px 4px 0 var(--black-10);background-color: #fff30f;margin:8px 0 5px 0;font-weight:700;display: inline-block;}
#             .amazon_widget .categList h3{font-weight: 500;}
#             .amazon_widget .categList .off{font-size:10px;z-index:1;position:absolute;top:10px;left:10px;color:#fff;font-weight:700;width: 125px;height:17px;text-align: left;}
#             .amazon_widget .categList figure span>img {z-index: -1;left: -10px;position: relative;width: 102px;height: 17px;top: -15px;}
#             .amazon_widget .nextprev-btn {top: 49%;position: absolute;width: 100%;}
#             .amazon_widget .nextprev-btn .btn {width: 26px;height: 25px;position: relative;z-index: 11;background-size: 312px;cursor: pointer;}
#             .amazon_widget .nextprev-btn .btn.prev-btn {background-position: -212px -2px;left: -13px;}
#             .amazon_widget .nextprev-btn .btn.next-btn {background-position: -241px -2px;right: -11px;}
#             .amazon_widget .nextprev-btn .btn.disable{opacity:0.5;cursor: not-allowed;}
#             .amazon_widget .moreNews{maqrgin-top:15px}
#
#                 .amazon_widget ul.categList li{text-align:left}
#                 .amazon_widget .categList figure{height:116px;border:none}
#                 .amazon_widget .categList h3{font-size:14px;font-family: 'Faustina', sans-serif;}
#             </style><div class="secWidget clearfix amazon_widget" data-ga-category="ET_HP_WEB"><h2 class="heading"><a href="/top-trending-products" target="_blank">Top Trending Products</a></h2><div class="overh"><div class="amazonSlider" data-ga-action="CategoryWidget_Click"><ul class="categList"><li><a data-ga-onclick="_1" href="/top-trending-products/major-appliances/air-conditioners/10-best-2-ton-split-air-conditioners-suitable-for-large-rooms/articleshow/97867722.cms" rel="sponsored nofollow" target="_blank"><figure><img alt="10 Best 2-Ton Split Air Conditioners Suitable for Large Rooms" data-original="https://img.etimg.com/photo/msid-97867722,imgsize-6444/10-best-2-ton-split-air-conditioners-suitable-for-large-rooms.jpg" src="https://img.etimg.com/photo/42031747.cms" title="10 Best 2-Ton Split Air Conditioners Suitable for Large Rooms"/></figure><h3>10 Best 2-Ton Split Air Conditioners Suitable for Large Rooms</h3></a></li><li><a data-ga-onclick="_2" href="/top-trending-products/major-appliances/air-conditioners/10-best-window-air-conditioners-for-this-summer-season/articleshow/97952822.cms" rel="sponsored nofollow" target="_blank"><figure><img alt="10 Best Window Air Conditioners for this Summer Season" data-original="https://img.etimg.com/photo/msid-97952822,imgsize-22660/10-best-window-air-conditioners-for-this-summer-season.jpg" src="https://img.etimg.com/photo/42031747.cms" title="10 Best Window Air Conditioners for this Summer Season"/></figure><h3>10 Best Window Air Conditioners for this Summer Season</h3></a></li><li><a data-ga-onclick="_3" href="/top-trending-products/major-appliances/air-conditioners/5-best-1-5-ton-acs-choose-from-windows-and-split-air-conditioners/articleshow/97919765.cms" rel="sponsored nofollow" target="_blank"><figure><img alt="5 Best 1.5-ton ACs: Choose from Windows and Split Air Conditioners" data-original="https://img.etimg.com/photo/msid-97919765,imgsize-9564/5-best-1-5-ton-acs-choose-from-windows-and-split-air-conditioners.jpg" src="https://img.etimg.com/photo/42031747.cms" title="5 Best 1.5-ton ACs: Choose from Windows and Split Air Conditioners"/></figure><h3>5 Best 1.5-ton ACs: Choose from Windows and Split Air Conditioners</h3></a></li><li><a data-ga-onclick="_4" href="/top-trending-products/electronics/accessories/buy-a-10000-mah-power-bank-starting-at-just-rs-899/articleshow/97995660.cms" rel="sponsored nofollow" target="_blank"><figure><img alt
my-innings-could-conclude-with-bharat-jodo-yatra-sonia-gandhi-at-congress-plenary-session/articleshow/98230721.cms"><img alt='"My innings could conclude with Bharat Jodo Yatra..." Sonia Gandhi at Congress plenary session' class="lazy flr" data-original="https://img.etimg.com/thumb/width-60,height-45,imgsize-1046864,msid-98230721,quality-100/my-innings-could-conclude-with-bharat-jodo-yatra-sonia-gandhi-at-congress-plenary-session.jpg" height="45" src="https://img.etimg.com/photo/42031747.cms" width="60"/></span><a data-ga-onclick="1 - href" href="/news/politics-and-nation/my-innings-could-conclude-with-bharat-jodo-yatra-sonia-gandhi-at-congress-plenary-session/articleshow/98230721.cms" target="_blank">"My innings could conclude with Bharat Jodo Yatra..." Sonia Gandhi at Congress plenary session</a></div><div class="stryList clearfix"><span data-ga-onclick="2 - href" href="/news/politics-and-nation/bjp-fuelling-fire-of-hatred-targeting-minorities-dalits-tribals-women-congress-leader-sonia-gandhi/articleshow/98229846.cms"><img alt="BJP fuelling fire of hatred, targeting minorities, Dalits, tribals, women: Congress leader Sonia Gandhi" class="lazy flr" data-original="https://img.etimg.com/thumb/width-60,height-45,imgsize-64548,msid-98229846,quality-100/bjp-fuelling-fire-of-hatred-targeting-minorities-dalits-tribals-women-congress-leader-sonia-gandhi.jpg" height="45" src="https://img.etimg.com/photo/42031747.cms" width="60"/></span><a data-ga-onclick="2 - href" href="/news/politics-and-nation/bjp-fuelling-fire-of-hatred-targeting-minorities-dalits-tribals-women-congress-leader-sonia-gandhi/articleshow/98229846.cms" target="_blank">BJP fuelling fire of hatred, targeting minorities, Dalits, tribals, women: Congress leader Sonia Gandhi</a></div><div class="stryList clearfix"><a data-ga-onclick="3 - href" href="/news/politics-and-nation/congress-to-provide-50-pc-reservation-to-scs-sts-obcs-minorities-women-youngsters-in-cwc/articleshow/98229653.cms" target="_blank">Congress to provide 50 pc reservation to SCs, STs, OBCs, minorities, women, youngsters in CWC</a></div><div class="stryList clearfix"><a data-ga-onclick="4 - href" href="/news/politics-and-nation/rs-1000-monthly-assistance-for-women-to-be-implemented-says-tn-cm/articleshow/98229619.cms" target="_blank">Rs 1,000 monthly assistance for women to be implemented, says TN CM</a></div><div class="stryList clearfix"><a data-ga-onclick="5 - href" href="/news/politics-and-nation/apne-baap-ka-samman-nahi-kar-paye-ho-yogi-lashes-out-at-akhilesh-in-up-assembly/articleshow/98228420.cms" target="_blank">"Apne baap ka samman nahi kar paye ho": Yogi Adityanath lashes out at Akhilesh in UP Assembly</a></div></div><div class="clr"></div><div class="moreNews flr"><a data-ga-onclick="More - href" href="/news/politics-nation" target="_blank">Politics</a> »</div></section><!--/home_otherwidget.cms?msid=1052732854&widget=politics&head=Politics&sidestry=true&link=/news/politics-nation&imageStry=2&noOfStry=5potime:37--></div><section class="clearfix"><div class="seoWidget" data-ga-action="Top Trending Terms Seo Widget" id="seoWrapper_rhs"><div class="prel"><div class="head">Top Trending Terms: </div><div class="nextprev-btn slider_embd"><div class="prev-btn arw_blk disable flt" data-ga-onclick="Previous | href"><span class="alft"></span></div><div class="ts-dots flt"><ul></ul></div><div class="next-btn arw_blk ryt flt" ...
#
#     		            if(typeof sessionStorage != 'undefined') {
#                             if(sessionStorage.getItem('stk_ftr_ad_rm')){
#                                 _log("stk_ftr_ad removed");
#                                 document.querySelectorAll(".stk_ftr_ad")[0].remove();
#                             }
#                             if(sessionStorage.getItem('stk_ftr_ad_exin_rm')){
#                                 _log("stk_ftr_ad_exin removed");
#                                 document.querySelectorAll(".stk_ftr_ad_exin")[0].remove();
#                             }
#                         }
#
# 		        </script><span class="hidden livetv_popup"></span><script src="https://js.etimg.com/d/js_jquery_cdn/v-1.cms" type="text/javascript"></script><script src="https://js.etimg.com/d/js_scripts_cdn/v-1.cms" type="text/javascript"></script><script>var language = '';</script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_common_new/v-533,minify-1.cms" type="text/javascript"></script><script defer="" onerror="errorLogs(this)" src="https://js.etimg.com/d/js_etidentifierv/v-23,minify-1.cms" type="text/javascript"></script><script defer="" onerror="errorLogs(this)" src="https://js.etimg.com/d/js_socialdatacapture_min/v-131,minify-1.cms" type="text/javascript"></script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_default_new2/v-72,minify-1.cms" type="text/javascript"></script><script>
#
# 				    var logAPIResponse = 1;
# 				$(document).ready(function () {
#                     var artCnt = customDimension.dimension94;
#                     if(objGdpr.allow() && artCnt && artCnt >= 3) {
#                         loadModule({'module_name': 'js_recommendation', v: 83, ref:'hpRecommendation'});
#                     }
#                     window.loadScript && loadScript('https://sf-objects-s3.tilc.in/sf-objects/cdnperf.js');
#                     var $jS = $.jStorage; if($jS.get('c_oneTapLogin') && $jS.getTTL('c_oneTapLogin') == 0) {$jS.deleteKey('c_oneTapLogin')}
#                 })
#
#                 </script><script>
# 	         if($('.main_container').length == 0) {
# 	            saveLogs({'type': 'main_container', 'container': 'missing'});
# 	            $('#pageContent,#sideBar').wrapAll('<div class="main_container"></div>');
# 	         }
#
# 	    </script><div data-adsslot="ET_ROS_NW/ET_ROS_Andbeyond_1x1" data-loc="All" data-size="[1, 1]" id="div-gpt-ad-1559650249467-0"></div><script type="text/javascript">
# 	    if(optParam != "1") {
#
# 	    try {
# 	        var _page_config;
# 	        var monthName = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'];
#             var IBDate = new Date();
#             var IBDateFmt = function() {
#                 return monthName[IBDate.getMonth()] +' '+IBDate.getDate()+', '+IBDate.getFullYear()+', 12.00 AM IST';
#             }
#             var ibeatDate = ''+ IBDateFmt() +'';
#             var _iBeat_cat = 'Home Page', _iBeat_subcat = '', _iBeat_catids = '2147477890,2160010';
#
#             _page_config = {
#                 host : 'economictimes.indiatimes.com',
#     			key : 'f66e70a45a565c9c76a526c5e9e99df',
#     			domain : 'economictimes.indiatimes.com',
#     			channel :  '',
#     			action : 1,
#     			articleId : 2160010,
#     			contentType: 20,
#             	location : 1,
#             	cat : 'Home Page',
#     			subcat : '',
#     			contenttag : '',
#     			catIds : '2147477890,2160010',
#     			articledt : ibeatDate,
#     			author : '',
#     			url : window.location.href,
#     			iBeatField : 'undefined'
#             }
#
#
#             var _ib_vct = 0;
#             if(ssoid = getCookie('ssoid')) {
#                 try {
#                     _ib_vct = 2;
#                     var jData = JSON.parse(localStorage.getItem('jStorage')),userData = jData && jData['prime_'+getCookie('TicketId')] || {}, up = userData.permissions || [];
#                     if(up.indexOf("subscribed") > -1) {
#     		            _ib_vct = 1;
#     		        } if (grx_up.length == 0) {
#     		            _ib_vct = 0;
#     		        }
# 		        } catch (e) {}
#             } else {
#                 _ib_vct = 3;
#             }
#
#             var _ibeat_track = {"visitor_cat" : _ib_vct}
#
#         } catch (e) {console.error('error', e);}
#
#
# 	    var secname="Home Page";
# 	   var agename='';
#
#
#
# 	    var _mfq = (_mfq || []), mouseflowPath = '/';
#
#
# 	    }
#
# 	    window.setColuuid && setColuuid();
# 	    window.ga && ga('set', {'dimension57': window.__tiluuid, 'dimension30': window._col_uuid});
#
# 	    </script><script>
#                      function invokeLogin(){
# 						try{
# 						isLoggedSso = getCookievaluetwitt('MSCSAuth');
# 						if(Get_Ckie('autologin')!=null){
# 							Delete_Ckie("autologin","/",".indiatimes.com");
# 						}
# 						tpbar1();
# 						}
# 						catch(ex)
# 						{
# 						}
# 						ga('send', 'event', 'Temp', 'invokeLogin', window.location.href);
# 					}
#
# 				</script><script type="text/javascript">
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({'pageTitle': document.title});
#
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-566NCXC');
#
#             </script><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-566NCXC" style="display:none;visibility:hidden" width="0"></iframe></noscript></body>

# %%
# Extract head of page
page_head = soup.head

# %%
page_head
# Out:
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><script>(function(){function m(u){var s=u+"=",b=document.cookie.split(";");for(var r=0;r<b.length;r++){var t=b[r];while(t.charAt(0)==" "){t=t.substring(1,t.length)}if(t.indexOf(s)==0){return t.substring(s.length,t.length)}}return null}var l=JSON.parse(localStorage.getItem("jStorage")||"{}")||{},c=l["prime_"+m("TicketId")]||{},q=l.userInfo,g=m("ssoid"),i=c.permissions||[],e=i.indexOf("subscribed")>-1?1:0,k="et_nhp_"+g,d=window.localStorage&&localStorage.getItem(k)||"",h=d.split("-"),n=document.getElementsByTagName("html")[0],p=location.href,o=(p.indexOf("dev8243")!=-1||p.indexOf("stg.")!=-1?0:1),a=new Date().getTime(),j=60*60*1000;
# function f(){window.location.href="/default_prime.cms";if(p.indexOf("fromsrc")!=-1&&p.indexOf("redeemvoucher")!=-1){window.location.href="/default_prime.cms"+window.location.search}}if(e&&q.email&&p.indexOf("dev=1")==-1){f()}})();<!--/defaultp_redirection.cms?minify=1potime:10--></script><link href="//economictimes.indiatimes.com/icons/etfavicon.ico" rel="shortcut icon"/><title>Business News Today: Read Latest Business news, India Business News Live, Share Market &amp; Economy News | The Economic Times</title><meta content="Saturday, February 25, 2023  03:25:00 PM" http-equiv="Last-Modified"/><meta content="Business news today: Read India Business news Live. Latest Business news and updates on Finance, share market, IPO, economy. Discover Business News Headlines, Top Financial News and more on The Economic Times." name="description"/><meta content="business news, india business news, business news today, latest business news, live business news, india business news live" name="keywords"/><link href="/manifest.cms" rel="manifest"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://cm.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://img.etimg.com" rel="preconnect"/><link href="https://js.etimg.com" rel="preconnect"/><link href="https://css.etimg.com" rel="preconnect"/><link href="https://sb.scorecardresearch.com" rel="preconnect"/><link href="https://ade.clmbtech.com" rel="preconnect"/><link href="https://www.googletagservices.com" rel="preconnect"/><link href="https://ads.pubmatic.com" rel="preconnect"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="https://static.clmbtech.com" rel="preconnect"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//connect.facebook.net" rel="dns-prefetch"/><link href="//cm.g.doubleclick.net" rel="dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://img.etimg.com" rel="dns-prefetch"/><link href="https://js.etimg.com" rel="dns-prefetch"/><link href="https://css.etimg.com" rel="dns-prefetch"/><link href="//sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://ade.clmbtech.com" rel="dns-prefetch"/><link href="https://jssocdn.indiatimes.com" rel="dns-prefetch"/><link href="https://jsso.indiatimes.com" rel="dns-prefetch"/><link href="https://static.growthrx.in" rel="dns-prefetch"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/faustina-v6-latin-500.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-500.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-600.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" fetchpriority="high" href="/fonts/montserrat-v14-latin-700.woff2" rel="preload" type="font/woff2"/><script>window.pageLoadStarted = (new Date()).getTime();</script><link as="script" fetchpriority="high" href="https://js.etimg.com/d/js_jquery_cdn/v-1.cms" rel="preload"/><link as="script" fetchpriority="high" href="https://js.etimg.com/d/js_scripts_cdn/v-1.cms" rel="preload"/><link as="script" fetchpriority="high" href="https://js.etimg.com/d/js_common_new/v-533,minify-1.cms" rel="preload"/><meta content="21540067693" property="fb:pages"/><link href="https://economictimes.indiatimes.com/icons/etfavicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://economictimes.indiatimes.com/thumb/width-120,height-120,msid-75267040/et.jpg" rel="apple-touch-icon"/><link href="https://c.amazon-adsy ...
# 	        function errorLogs(data, fallback) { if(data && window.location.search.indexOf('utm_source') == -1) { try { var o = window.location.origin, isLive = (o.indexOf('dev') == -1 && o.indexOf('pwa') == -1 ? 1 : 0), url = data.href || data.src || '', type = (data.localName || data.tagName) + (data.attributes.fallbackfile ? ' fallbackfile': ''), ua = window.navigator && window.navigator.userAgent; var logdata = "logdata=" + JSON.stringify({mode: (isLive ? 'modeLive' : 'modeDev'), channel:'Error_desktop', type:type, data:encodeURIComponent(url), userAgent: ua, url: window.location.href}); var xhr = new XMLHttpRequest(); xhr.withCredentials = true; xhr.open("POST", "https://etx.indiatimes.com/log?et=errorLogs"); xhr.setRequestHeader("Content-Type", "application/x-www-form-urlencoded"); xhr.send(logdata); var fpArr = url.split('.com'), fp = fpArr[1], ft = fp.indexOf('js_') != -1 && 'js' || fp.indexOf('css_') != -1 && 'css'; !fallback && loadAssets(ft, fp); } catch (e) {} } }
#
# 	        function loadAssets(t, f) {
# 	            //f = f + (f.indexOf('?')!=-1?'&':'?')+'ref=fallbackFile'
#                 if (t=="js"){
#                     var fileref=document.createElement('script')
#                     fileref.setAttribute("type","text/javascript")
#                     fileref.setAttribute("src", f)
#                 } else if (t=="css"){
#                     var fileref=document.createElement("link")
#                     fileref.setAttribute("rel", "stylesheet")
#                     fileref.setAttribute("type", "text/css")
#                     fileref.setAttribute("href", f)
#                 }
#                 if (typeof fileref!="undefined"){
#                     fileref.setAttribute("fallbackfile", "1")
#                     fileref.setAttribute("onerror", "errorLogs(this, 1)")
#                     document.getElementsByTagName("head")[0].appendChild(fileref)
#                 }
#             }
#
# 	    </script><link fetchpriority="high" href="https://css.etimg.com/d/et_fonts/v-13,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link fetchpriority="high" href="https://css.etimg.com/d/css_main/v-51,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><link as="style" href="https://css.etimg.com/d/css_common_new/v-291,minify-1.cms" onerror="errorLogs(this)" onload="this.rel='stylesheet'" rel="preload" type="text/css"/><noscript><link href="https://css.etimg.com/d/css_common_new/v-291,minify-1.cms" rel="stylesheet"/></noscript><link href="https://css.etimg.com/d/css_default_new2/v-57,minify-1.cms" onerror="errorLogs(this)" rel="stylesheet" type="text/css"/><script>(function() {var lh = location.host; if(lh.indexOf('economictimes.com') == -1 && lh.indexOf('india'+'times'+'.com') == -1 && lh.indexOf('archive'+'.org') == -1 && lh.indexOf('webcache' + '.googleusercontent'+ '.com') == -1) { window.location.href = 'https' + '://' + 'economictimes' + '.indiatimes.'+ 'com' + '?frmref=' + location.host }})()</script><script>
#
# 	        function getCookie(n) {var ne = n + "=", ca = document.cookie.split(';');for (var i=0;i< ca.length;i++){ var c = ca[i]; while (c.charAt(0) == ' ') c = c.substring(1, c.length); if (c.indexOf(ne) == 0) return c.substring(ne.length, c.length); } return null; }
#
#
# 	    var objVc = {env:'live',version_on:'2023.02.25 15:17',vcLScacheTime:'10',js_etsubscription:'2',js_onboarding_popup_sh:'13',js_comments:'111',js_googleslock:'782',js_googlelogin:'69',js_common_buydirect:'752',js_bookmark:'24',js_follow:'12',js_highcharts:'4',js_highcharts3d:'2',js_googlecharts:'1',js_sr_search:'1',js_ask_the_expert_crypto:'16',js_articleshow_main:'229',css_articleshow_new:'111',js_login:'101',js_datepicker:'2',js_push:'61',js_athena_distribution:'30',js_athena_distribution_wap:'27',js_slikeplayernew:'18',js_access_prime_pass:'4',js_prime_access_functions:'4',css_buydirect:'14',css_commoncalc:'29',js_tradenow:'26',interstitial_web:'1',int_countrychk_web:'1',int_allowedcountry_web:'1,2,3,4,5,6',int_fequencycap_web:'4',extended_fcap_hrs_web:'18',js_common_wap:'344',js_common_markets_wap:'11',js_watchlist_wap:'15',js_sr_search_wap:'8',js_ask_the_expert_crypto_wap:'16',js_athenalive_wap:'87',js_commonall:'143',js_bookmark_wap:'13',js_socialdatacapture_min_wap:'46',wap_interstitial_start:'Jun 03, 2021 23:59:00',wap_interstitial_end:'Mar 31, 2023 23:59:00',int_countrychk_wap:'0',int_allowedcountry_wap:'1,2',cpd_wap:'1',lib_login:'/js_feed/jsso_crosswalk_legacy_min.cms',live_tv_skin:'0',global_cube:'0',global_cube_wap:'0',global_cube_faces:'2',global_cube_fullad:'0',global_cube_landingon:'sensex',global_cube_wap_url:'https://m.economictimes.com/iframe_cube.cms',currency_ad_wap:'1',site_sync:'0',ticker_ad:'0',ticker_ad_desktop_only:'0',aff_package:'bnsov',aff_package_wap:'bnsov',ticker_ad_home:'0',adx:'1',logAdsStatus:'0',amazon_bidding:'0',amazon_tam:'1',amazon_tam_web:'0',js_newsltrpopup:'126',nlExpiry:'864000',nlReloadExpiry:'30',js_primetargeting_popup:'9',js_inappmsg:'8',plan_on_paywall:'0',skip_trial:'100',planEntryPointCache:'3',trackAdCode:'0',ajaxError:'1',cTId:'WWW-R7W-Z45Z',oauth:'oauth2',oauthClientId:'b2a8e883ec676f417520f422068a4742',planPage:'/plans.cms',planPageTest:'https://economictimes.indiatimes.com/plans.cms',planPageM:'https://m.economictimes.com/plans.cms',subscriptions:'subscriptions',krypton:'kryptonp',apw:'apw',nlSubscribe:'etsub3',exp_login2plan:'0',js_ratingwidget:'9',js_swg:'4',swg:'1',login_paywall:'Starting @ <strike>Rs150</strike> Rs120/month',singularPlanExp:'0',intro_offer_banner:'0',ctaTxtExp:'50',mf_defaultTab:'1',intro_offer:'0',article_recommendations:'100',primeTargeting:'1',skipnlpopup:'1',skipCryptoPopup:'1',js_article_recommendations:'21',skiparticle_recommendations_rhs:'1',skiparticle_recommendations_in:'1',skipwhatsapp_banner:'1',liveTvLsName:'bandTvCheckPlayed3',liveTvLsValue:'3600',survicate_loyaluser_count:'15',js_etbenefits:'36',js_tponboarding:'3',js_giftstory:'11',disable_MFOP_wap:'1',missedStoryPercent:'30',missedStoryDays:'7',missedStoryMinCount:'3',guestOTPEnabled:'0',paywallSubscriberFlow:'0',js_paywallsubflow:'3',signinwallSubscriberFlow:'50',web_productIntervention:'0111101010',wap_productIntervention:'100101011',mktTopAppDownloader:'1',mktBottomAppDownloader:'1',stocksRecoPopup:'0',paywall_mloffer:'0',onboarding_tpoffer:'1',ml_flag:'0',budget2023_livetv_onOff:'0',budget2023_tv_lBStartTime:'240',budget2023_tv_lBVisibiltyTime:'10',dummy:''};
#         (function(){
#
#             try {var lsd = localStorage.getItem('objVc'), lsdj = lsd && JSON.parse(lsd) || '', vo = objVc.version_on, lv = new Date(vo), sv = lsdj && lsdj.version_on && new Date(lsdj.version_on) || 0, diff = (sv-lv) / 60000;
#                 if(sv && diff >= 0) {objVc = lsdj;}
#                 else {
#                     var now = Date(), vodo = new Date(vo);
#                     objVc.lsTime = vodo > now ? now.toString() : vo; localStorage.setItem('objVc', JSON.stringify(objVc))
#                 }
#                 if(window.location.search.indexOf('skip_popup=1') != -1) { objVc.skipPopup = 1; }
#             } catch(e) {}
#
#         })()
#         </script><iframe height="0" id="__tiluuid_frame" style="display:none" width="0"></iframe><script>
# 		try {
# 		var __tiluuid = localStorage.getItem('__tiluuid');
#         var __tiluuid_expiry_ms = parseInt(localStorage.getItem('__tiluuid_expiry_ms')) || 1607000000410;
#         if (__tiluuid_expiry_ms <= (new Date()).getTime() || localStorage.getItem('__tiluuid') == null) {
#             function receiveMessage(evt) {
#                 if (evt.origin === 'https://tilanalytics.timesinternet.in') {
#                     if (evt.data && evt.data.__tiluuid) {
#                         __tiluuid = evt.data.__tiluuid;
#                         localStorage.setItem('__tiluuid', __tiluuid);
#                         var isValid = /^[0-9A-F]{8}-[0-9A-F]{4}-4[0-9A-F]{3}-[89AB][0-9A-F]{3}-[0-9A-F]{12}-[0-9]+$/i.test(__tiluuid);
#                         if (isValid) {
#                             localStorage.setItem('__tiluuid_expiry_ms', evt.data.__tiluuid_expiry_ms);
# 							try {
# 							 if (ga){ ga('set', {'dimension57': __tiluuid});}
# 						 	}catch(e) {}
#
#                         }
#                         if (evt.data.reset === true && evt.data.__tiluuid_reset_script_path) {
#                             var reset_tiluuid_element = document.createElement("script");
#                             reset_tiluuid_element.setAttribute("src", (evt.data.__tiluuid_reset_script_path));
#                             document.head.appendChild(reset_tiluuid_element);
#                         }
#                     }
#                 }
#             }
#
#             window.addEventListener('message', receiveMessage, false);
#             document.getElementById("__tiluuid_frame").src = 'https://tilanalytics.timesinternet.in/production/frame-2.1.min.html';
#         }
#
#         var _col_uuid;
#         function setColuuid(){for(var o="_col_uuid=",n=decodeURIComponent(document.cookie).split(";"),t=0;t<n.length;t++){for(var u=n[t];" "==u.charAt(0);)u=u.substring(1);0==u.indexOf(o)&&(_col_uuid=u.substring(o.length,u.length))}};
#         setColuuid();
#
#         }catch(e) {}
# 		    </script><!--/tiluuidscript.cmspotime:4--><script id="geo_script" src="https://economictimes.indiatimes.com/geoapiet?cb=et" type="text/javascript"></script><script>
# 		    geolocation = window.geoinfo && window.geoinfo.geolocation || '';
# 			if(window.localStorage && localStorage.getItem('temp_geolocation')) {var geolocation = localStorage.getItem('temp_geolocation');}
# 		    function allowGDPR() {
# 		        var flag = false, ginfo = window.geoinfo || {};
# 		        if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {flag = true;}
# 		        return flag;
# 		    }
# 		    allowGdpr = (function () {
#                 var flag = 0, ginfo = window.geoinfo || {};
#                 // if not EU(5), and (not US(2) if US(2) then not california(CA))
#                 if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {
#                     flag = 1;
#                 }
#                 return flag;
# 		    })()
# 		    </script><!--/geolocationscript.cmspotime:4--><script>
# 		    var urlParams =window.location.search ? window.location.search : "";
#
#
# 		            var ext_param_check=-1==urlParams.indexOf("utm_medium=display_ext"),aff_param_check=-1==urlParams.indexOf("utm_medium=display_aff");aff_param_check||sessionStorage.setItem("aff_campaign","1"),ext_param_check&&aff_param_check&&function(){objVc=window.objVc||{};var e=objVc.int_countrychk_web?parseInt(objVc.int_countrychk_web):1,t=objVc.int_allowedcountry_web;t=t&&t.split?t.split(","):["1"];var i=objVc.int_fequencycap_web?parseInt(objVc.int_fequencycap_web):3,o=(new Date).getHours();"undefined"!=typeof objVc&&0!=objVc.extended_fcap_hrs_web&&o>=objVc.extended_fcap_hrs_web&&(i+=1);var a={setCookieToSpecificTime:function(e,t,i,o){try{var a=".indiatimes.com",n="";if(e&&t&&i&&(n=e+"="+escape(t)+"; expires="+new Date((new Date).toDateString()+" "+i).toUTCString()+"; domain="+a+"; path=/;"),e&&t&&o){var r=new Date;r.setSeconds(r.getSeconds()+o),n=e+"="+(escape(t)+(null==o?"":"; expires="+r.toUTCString())+"; domain="+a+"; path=/;")}document.cookie=n}catch(e){}},init:function(){var e=1==objVc.interstitial_web?1:0;if(-1!=window.location.search.indexOf("ints=0")&&(e=0),e){var t=getCookie("TicketId"),i=a.getOauthJStorage(t),o=i&&i.permissions||[],n=-1==o.indexOf("subscribed")||-1==o.indexOf("etadfree_subscribed")||0==o.length||0,r=getCookie("ssoid")||getCookie("MSCSAuthID");(!r||r&&!n)&&a.loadInterstitial()}},getDeviceType:function(){try{var e=navigator.userAgent;return/(tablet|ipad|playbook|silk)|(android(?!.*mobi))/i.test(e)?"tablet":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Kindle|Silk-Accelerated|(hpw|web)OS|Opera M(obi|ini)/.test(e)?"mobile":"desktop"}catch(e){console.log("getDeviceType:"+e)}},loadInterstitial:function(){try{var o=document.referrer;if(!(o.indexOf("/ad-free/success")>-1||o.indexOf("/ad-free/subscribed"))>-1||localStorage.getItem("devTool")){window.location;var n=navigator&&navigator.userAgent&&navigator.userAgent.toLowerCase()||"",r=-1!=n.indexOf("bot"),c=-1!=n.indexOf("lighthouse"),s=-1!=n.indexOf("insights"),d=-1!=n.indexOf("ptst/");isWebPageTest=-1!=n.indexOf("ptst_x/");var f=getCookie("int_fcapcount")||0,l=getCookie("et_interstitial_active"),g=window.geoinfo&&geoinfo.geolocation||"1",p=t.indexOf(g);if(!("mobile"==a.getDeviceType()||r||c||s||isWebPageTest||d||l||!(f<i)||0!=e&&-1==p)){a.setCookieToSpecificTime("et_interstitial_active","true","",30);var _=parseInt(f)+1;_<=i&&a.setCookieToSpecificTime("int_fcapcount",_,"23:59:59"),window.sessionStorage&&window.sessionStorage.setItem("intsRef",window.location.href);return window.location.replace("/defaultinterstitial.cms"),!1}}}catch(e){window.errorLogs&&errorLogs({href:JSON.stringify(objVc),localName:"interstitial_error",attributes:""},1)}},getOauthJStorage:function(e){try{return jStorageData=window.localStorage&&localStorage.jStorage?JSON.parse(localStorage.jStorage):{},jStorageData["prime_"+e]}catch(e){}}};a.init()}();
#
# 		        </script><!--/interstitialscript.cms?v=18potime:3--><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_monetize/v-163,minify-1.cms" type="text/javascript"></script><script async="async" fetchpriority="low" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script><script type="text/javascript">
# 	        var optParam = '';
# 	        try {
# 	        var urlParams = window.URLSearchParams && new URLSearchParams(window.location.search),
# 	            optParam = urlParams.get && urlParams.get('opt');
# 	        } catch (e) {}
#
# 	        var objSec = {template: 'default', msid:'2160010', isHome:1, secNames: [],secIds:['2147477890']};
#         var tmplName = tpName = 'default',lang = '',nav_sec1,newHookId,subsec1_value,subsec1_common = '0',newHookId2,subsec2_value,subsec2_common = '0',subsec3_common = '0';
#         var objDim = {d52:'nature_of_content',d96:'continuous_paywall_hits',d112:'ml_status',d95:'monthly_article_count',d113:'ml_score',d10:'user_login_status_hit',d54:'content_shelf_life',d98:'daily_paid_article_count',d110:'paywall_signaling',d53:'content_target_audience',d97:'monthly_paid_article_count',d111:'response_source',d12:'tags_meta_keyword',d56:'degree_of_conten',d11:'content_theme_the_primary_tag',d55:'content_tone',d14:'special_coverage',d58:'et_product_item',d13:'article_publish_time',d16:'video_embed',d15:'audio_embed',d59:'show_paywall_final',d117:'video_status',d61:'paywall_probability',d114:'ml_threshold_value',d60:'paywall_score',d115:'adaptive_status',d63:'paid_articles_read',d62:'eligibility_paywall_rule',d65:'bureau_articles_read',d20:'platform',d64:'free_articles_read',d23:'author_id',d67:'loyalty',d66:'article_length',d25:'page_template',d24:'syft_initiate_page',d68:'paywall_hits',d27:'site_sub_section',d26:'site_section',d29:'section_id',d28:'prime_deal_code',d109:'user_region',d70:'us_election_2020',d72:'paywall_experiment',d71:'plan_group_id',d32:'prime_article_read_before_syft',d75:'watchlist_active_status',d34:'content_age',d33:'prime_article_read_before_success',d36:'sign_in_initiation_position',d35:'subscription_method_hit',d37:'user_subscription_status',d1:'et_product',d2:'blocker_type',d3:'user_login_status_session',d4:'agency',d5:'author_name',d6:'cms_content_publishing_type',d7:'content_personalisation_level',d8:'article_publish_date',d9:'sub_section_name',d40:'freeread',d45:'prime_hp_ui_template',d47:'prime_hp_ui_content_b_color',d46:'prime_hp_ui_content_size',d49:'syft_initiate_position',d48:'content_msid',d92:'last_click_source',d50:'signin_initiate_page',d94:'daily_article_count',d93:'internal_source'};var serverTime = '02.25.2023 15:20:01';var WRInitTime=(new Date()).getTime();
#             (function () {if (self !== top) {var e = function (s) {return document.getElementsByTagName(s)}; e("head")[0].innerHTML = '<style>*{display:none;}</style>'; setTimeout(function () {e("body")[0].innerHTML = ''; var hEle = e("html")[0]; hEle.innerHTML = '<a href="' + self.location + '" target="_blank">economictimes.indiatimes.com</a>'; hEle.className = ''; top.location = self.location; }, 0);}})();
#
#         _log = window.console && console.log ? console.log : function () {};
# 		// Creating Elements for IE : HTML 5 and cross domain checks
# 		(function () {
#     		try {
#     		    var elem = ["article", "aside", "figure", "footer", "figcaption", "header", "nav", "section", "time"];
#     		    for(var i=0; i<=elem.length-1; i++) {document.createElement(elem[i])} var hd = 'indiatimes.com', dd = document.domain,intv,intv2,fo; if (dd != hd && dd.indexOf(hd) != -1) {document.domain = hd}
#     		}catch(e){}
# 		})();
# 		var intv,intv2;var fo;
# 		if(subsec1_value == '1715249553' && subsec2_value == '1052732854'){
# 			subsec1_value = newHookId = '1052732854'; // politicsnation
# 		}else if(subsec1_value == '1715249553' && subsec2_value == '1373380680'){
# 			subsec1_value = newHookId = '1373380680'; // Economy
# 		}
#
# 		if(optParam != "1") {
#
#
# 	    customDimension = window.customDimension || {};
# 	    function setDim(dim, val, init) { try { if(dim) { var key = 'dimension' + dim, objDim = {}; objDim[key] = val; customDimension[key] = val; init && ga('set', objDim); } }catch(e){} }
#
#
#                 var _gaq = _gaq || [];
#                 var customDimension = customDimension || {};
#                 var analytics_js_path = 'https://www.google-analytics.com/analytics.js';
#                 (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                 })(window,document,'script',analytics_js_path,'ga');
#                 var gaProperty = 'UA-198011-5';
#                 var disableStr = 'ga-disable';
#                 if (document.cookie.indexOf(disableStr + '=true') > -1) { window[disableStr + '-' + gaProperty] = true; }
#
#                 ga('set', 'anonymizeIp', true);
#                 ga('create', gaProperty, 'auto', {'allowLinker': true});
#                 ga('require', 'linker');
#                 ga('linker:autoLink', ['economictimes.com']);
#                 ga('require', 'displayfeatures');
#                 try {
#                     var et_ua = window.navigator && navigator.userAgent.toLowerCase() || '';
#                     if(et_ua.indexOf('bot') == -1 && et_ua.indexOf('lighthouse') == -1 && et_ua.indexOf('ptst/') == -1 && et_ua.indexOf('speed insights') == -1) {
#                         window.optimizely = window.optimizely || [];
#                         window.optimizely.push("activateUniversalAnalytics");
#                         ga('require', 'GTM-WV452H7');
#                     }
#                 } catch (e) {}
#
#                 (function () {
#                     setDim(25,"default");
#                     setDim(26,"Home");
#                     setDim(27,"Home");
#                     setDim(29,"0");
#                     setDim(48,"2160010");
#                     setDim(30,window._col_uuid);setDim(57,window.__tiluuid);
#
#
#                     if(window.geolocation) {setDim(109, window.geolocation == 1 ? 'IND' : 'INTER');}
#                     var a = window.localStorage && localStorage.getItem('et_syftCounter') || '';
#                     a = a && JSON.parse(a) || {};
#                     if(a.beforeSyft) {setDim(32,a.beforeSyft);}
#                     if(a.afterSyft) {setDim(33,a.afterSyft);}
#                 })()
#
#
#
# 	    var trafficSource = '';
# 	    function getjStorageVal(keyName) { var jString = localStorage.getItem("jStorage"), value = ''; try { if(jString) { var objJstorage = JSON.parse(jString); value = objJstorage[keyName] ? objJstorage[keyName] : ''; } } catch (e) {} return value; }
# 		(function () {
# 		    function addZero(num) {return (num >= 0 && num < 10) ? '0' + num : num;}
# 		    try {
#     		    lastClick = getjStorageVal('etu_last_click');
#                 if(!lastClick) {
#                     lastClick = document.referrer.indexOf('indiatimes.com') == -1 ? 'direct_landing_articleshow' : 'other';
#                 }
#                 var dref = document.referrer, wlh = window.location.href.toLowerCase(), wlp = window.location.pathname;
#                 if(/google|bing|yahoo/ig.test(dref)) {trafficSource = 'organic';}
#                 else if(/facebook|linkedin|instagram|twitter/ig.test(dref) || wlh.indexOf('utm_medium=social') != -1) { trafficSource = 'social';}
#                 else if(wlh.indexOf('utm_medium=email') != -1) {trafficSource = 'newsletter'; }
#                 else if(wlh.indexOf('utm_source=etnotifications') != -1) {trafficSource = 'notifications'; }
#                 else if(getjStorageVal('etu_source')) { trafficSource = getjStorageVal('etu_source');}
#
#                 if(!trafficSource) {
#                     if(wlp == '/' || wlp == '/default.cms') {trafficSource = 'direct'}
#                     else if(wlp.indexOf('articleshow')) {trafficSource = 'organic'}
#                     else {trafficSource = 'other'}
#                 }
#
#                 var dtObject = new Date(), dt = (dtObject.getFullYear() + '' + addZero(dtObject.getMonth() + 1) + '' + addZero(dtObject.getDate())), key = 'et_article_' + dt;
#                 var articleReadCountToday = (getjStorageVal(key) || []).length;
#                 var articleReadCountMonth = 0;
#                 var paidArticleReadCountMonth = 0;
#                 var jString = localStorage.getItem("jStorage");
#                 try {
#                     if(jString) {
#                         var objJstorage = JSON.parse(jString);
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_article_') != -1}).forEach(function (key) { articleReadCountMonth += getjStorageVal(key).length});
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_primearticle_') != -1}).forEach(function (key) { paidArticleReadCountMonth += getjStorageVal(key) || 0});
#                     }
# 	            } catch (e) {}
#
#                 var paidArticleReadCountTodayKey = 'et_primearticle_' + dt;
#                 var paidArticleReadCountToday = getjStorageVal(paidArticleReadCountTodayKey) || 0;
#                 var continuousPaywallList = getjStorageVal('et_continuousPaywalled') || [];
#
#
#                 setDim(92, lastClick);
#                 setDim(93, trafficSource);
#                 setDim(94, articleReadCountToday);
#                 setDim(95, articleReadCountMonth);
#                 setDim(96, continuousPaywallList.length);
#                 setDim(97, paidArticleReadCountMonth);
#                 setDim(98, paidArticleReadCountToday);
#
#                 var subsStatus = '-', d3 = 'NONLOGGEDIN';
#                 var jData = JSON.parse(localStorage.getItem('jStorage'));
#                 var b = document.getElementsByTagName('html')[0];
#                 if(ssoid = getCookie('ssoid')) {
#                     try {
#                         d3 = 'LOGGEDIN';
#                         var grx_userData = jData && jData['prime_'+getCookie('TicketId')] || {};
#                         grx_userData = grx_userData || {};
#                         var grx_up = grx_userData.permissions || [];
#                         if(grx_up.indexOf("expired_subscription") > -1) {
#                             subsStatus = 'Expired User';
#         		        } else if (grx_up.indexOf("subscribed") > -1 && grx_up.indexOf("cancelled_subscription") > -1 && grx_up.indexOf("can_buy_subscription") > -1) {
#         		            subsStatus = 'Paid User - In Trial';
#         		            b.classList.add("cancelled_user");
#         		        } else if(grx_up.indexOf("subscribed") > -1) {
#         		            subsStatus = 'Paid User';
#                             b.classList.add("prime_user");
#         		        } else if(grx_up.indexOf("etadfree_subscribed") > -1) {
#         		            subsStatus = 'Ad Free User';
#         		        } else if (grx_up.length == 0) {
#         		            subsStatus = 'Permission Missing';
#         		        } else {
#         		            subsStatus = 'Free User';
#         		        }
#
#         		        if(grx_up.indexOf("subscribed") > -1) {
#         		            b.classList.add("prime_header");
#         		        }
#     		        } catch (e) {}
#                 } else {
#                     subsStatus = 'Free User';
#                 }
#
#                 if(subsStatus == '-' || subsStatus == '' || subsStatus == 'Expired User' || subsStatus == 'Free User') {
#                     b.classList.add("free_user");
#                 }
#                 setDim(3, d3); setDim(10, d3); setDim(37, subsStatus);
#
# 		    } catch (e) {}
# 		})();
#
#
# 	    setDim(1,'homepage');setDim(24,'homepage');
#
#                 ga('send', 'pageview', customDimension);
#
#
#     		    var newHookId ='0';
#
#         			var subsec1_value ='0', subsec1_2value = '0';
#
#     			        if(subsec1_value == '1715249553' && subsec1_2value == '1052732854'){
#     			            subsec1_value = '1052732854'; // politicsnation
#     			        }else if(subsec1_value == '1715249553' && subsec1_2value == '1373380680'){
#     			            subsec1_value = '1373380680'; // Economy
#     			        }
#
#
#
#         (function (g, r, o, w, t, h, rx) {
#             g[t] = g[t] || function () {(g[t].q = g[t].q || []).push(arguments)
#             }, g[t].l = 1 * new Date();
#             g[t] = g[t] || {}, h = r.createElement(o), rx = r.getElementsByTagName(o)[0];
#             h.async = 1;h.src = w;rx.parentNode.insertBefore(h, rx)
#         })(window, document, 'script', 'https://static.growthrx.in/js/v2/web-sdk.js', 'grx');
#         grx('init', 'gf999c70d');
#         var grxDimension = {url: window.location.href, title : document.title, referral_url : document.referrer, platform: 'desktop'};
#         var pfuuid = getCookie('pfuuid');
#         if(pfuuid) { grxDimension['et_uuid'] = pfuuid}
#
#         grx('config',"service_worker","/et_serviceworker.cms");
#         grx('config',"applicationServerKey","BIEYq99VozBXu5wtCtElr19cYzEZCgSZAYV5amfqzU1IWrR8SWr5T0Htp72bVbslw08rhMJvkrRFT_11HS8zz5c");
#         var isSafari = /^((?!chrome|android).)*safari/i.test(navigator.userAgent);
#         var isPlanPage = "false";
#         var isLoginPage = "false";
#
#         if(isPlanPage === "false" && isLoginPage === "false" && !isSafari) {
#             grx('enableCustompopup');
#         }
#
#
#
#             (function () {
#                 grx('userId', getCookie('ssoid') || '-');
#                 try {
#                     if(window.localStorage && localStorage.getItem) {
#                         var jString = localStorage.getItem("jStorage");
#                         if(jString) {
#                             var objJstorage = JSON.parse(jString), objProf = objJstorage['et_subscription_profile'], userInfo = objJstorage['userInfo'] || {}, peuuid = getCookie('peuuid'), pfuuid = getCookie('pfuuid');
#                             for (var attrname in objProf) { grxDimension[attrname] = objProf[attrname]; };
#                             var dt = new Date(), tDate = dt.getDate()+'-'+(dt.getMonth()+1)+'-'+dt.getFullYear(),loggedIn = (getCookie('ssoid') ? 'Y' : 'N');
#                             grxDimension['first_date_on_et'] = objJstorage['et_first_date'] || tDate;
#                             grxDimension['last_visited_date'] = tDate;
#                             grxDimension['logged_in'] = userInfo['email'] ? 'Y' : 'N';
#                             grxDimension['email'] = userInfo['email'] || '-';
#                             grxDimension['first_name'] = userInfo['fname'] || '-';
#                             grxDimension['last_name'] = userInfo['lname'] || '-';
#                             grxDimension['current_subscriber_status'] = customDimension.dimension37 || '-';
#                             if(peuuid) {grxDimension['web_peuuid'] = peuuid;}
#                             if(pfuuid) {grxDimension['web_pfuuid'] = pfuuid;}
#                         }
#                     }
#                     if(window.customDimension && window.objDim) {
#                         for(key in customDimension) {
#                             var dimId = 'd' + key.substr(9, key.length);
#                             if(objDim[dimId] && typeof customDimension[key] != 'undefined') { grxDimension[objDim[dimId]] = customDimension[key]; }
#                         }
#                     }
#                 }catch(e) {
#                     console.log('Error profile Dimension');
#                 }
#             })()
#
#         grx('track', 'page_view', grxDimension);
#
#             var _comscore = _comscore || [];
#             _comscore.push({ c1: "2", c2: "6036484"});
#
#             if(window.allowGdpr == 1) {
#                 (function() {
#                     var s = document.createElement('script'), el = document.getElementsByTagName("script")[0]; s.async = true;
#                     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#                     el.parentNode.insertBefore(s, el);
#                 })();
#             }
#
#
#
#                 if(window.allowGdpr == 1) {
#                     (function() {
#             			function pingIbeat() {
#                 			window._pg_endpt=(new Date()).getTime();
#                 			var e = document.createElement('script');
#                 			e.setAttribute('language', 'javascript');
#                 			e.setAttribute('type', 'text/javascript');
#                 			e.setAttribute('async', true);
#                 			var dt = window.dateFormat ? dateFormat(new Date(), '%Y%M%d') : 1;
#                 			var sd = window.objDomain && objDomain.js || '';
#                 			e.setAttribute('src', sd + '/js_ibeat_ext.cms?ver=9&v=' + dt);
#                 			if((window.location.href.indexOf('etdev8'))>-1 || (window.location.href.indexOf('etstg'))>-1) {
#                 			    e.setAttribute('src', "https://agi-static.indiatimes.com/cms-common/stg/stg-ibeat.min.js");
#                 			}
#                 			document.head.appendChild(e);
#             			}
#             			if(typeof window.addEventListener == 'function') {
#             			    window.addEventListener("load", pingIbeat, false);
#             			} else {
#                 			var oldonload = window.onload;
#                 			window.onload = (typeof window.onload != 'function') ?
#                 			pingIbeat : function() { oldonload(); pingIbeat(); };
#             			}
#             		})();
#                 }
#
#
#         }
# 	    </script><script type="application/ld+json">
#         	    {
#         	        "@context" : "https://schema.org",
#         		  	"@type": "NewsMediaOrganization",
#         		  	"name": "Economic Times",
#         		    "url" : "https://economictimes.indiatimes.com/","sameAs" : [ "https://www.facebook.com/EconomicTimes","https://twitter.com/economictimes","https://plus.google.com/+TheEconomicTimes"],
#         		    "logo": {
#         		      "@type": "ImageObject",
#             	      "url": "https://img.etimg.com/thumb/msid-76939477,width-600,height-60,quality-100/economictimes.jpg",
#         		      "width": 600,
#         		      "height": 60
#         		    }
#         		  }
#             </script><script>
# 				    var subsec1_value = '';
# 				    var skinningExist=false;
# 				        /*ints = '1', // 0 -> inactive, 1 -> active
# 				        intsCountryChk = 1, // 1 -> if target to specific location, 0 -> no location
# 				        intsAllowedCountry = [1], // please mark ids without quote e.g [2,3,4]
# 				        intsFequencyCap = 3,
# 				        intsPath = '/defaultinterstitial.cms';*/
# 				        // intsPath = '/configspace/etmain_static/content/defaultinterstitial.html';
#
#
#         				function getQueryParams(qs) {
#         			        qs = qs.split('+').join(' ');
#         			        var params = {},
#         			            tokens,
#         			            re = /[?&]?([^=]+)=([^&]*)/g;
#         			        while (tokens = re.exec(qs)) {
#         			            params[decodeURIComponent(tokens[1])] = decodeURIComponent(tokens[2]);
#         			        }
#         			        return params;
#     			        }
#         			    /*var query = getQueryParams(document.location.search);
#
#     				    ints = query.ints ? query.ints : ints;*/
#                      	// var homePageRedirectTo = '/budget';
#
# 				</script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/jshome_topnew/v-58,minify-1.cms" type="text/javascript"></script><style>
#                     .livetv_cont{position:relative;}
#                     .livetv_layer{position:absolute;width: 152px; height: 114px;z-index:1;cursor:pointer;}
#                     .free_user #topStories [data-p='24'] h2 a{font-size: 14px;font-weight:500;}
#                     .free_user #topStories [data-p='24'] img.smallImg{display:none;}
#                     .mainLead{text-align:center;margin:0 0 30px 0}
#                     .mainLead .main a{font-size:32px;color:#000;font-weight: 700;margin-bottom: 10px;font-family:'Faustina',sans-serif;}
#                     .prime_user .iframeyt{display:none;}
#                     .main_container a:visited:not(.skip_vcolor):not(h2 a):not(h4 a):not(.head a):not(.top_mf_wdgt a):not(#sportlight_mf a):not(.moreNews a):not(.Ntxt a), .newsByInd h4 a:visited { color: #636363; }
#                     /*header.header {background-image: url(https://img.etimg.com/photo/94940834.cms);margin: 0 auto;box-sizing: border-box;display: table;width: 1003px;position: relative;padding: 7px 0;z-index: 2;min-height: 110px;background-size:1000px;}*/
#                 </style></head>

# %%
# print the result
print(page_body, page_head)
# Out:
# <body><div data-adsslot="ET_Home/ET_Home_Home/ET_HP_Skin_RHS_125" data-loc="All" data-size="[[160, 600], [125, 600],[120,600]]" id="div-gpt-ad-14245244223081-0-oop1" style="position: fixed; top: 0px; left: 0; margin-left: calc((100% - 1003px) / 2 - -1004px);"></div><div class="skinning_left" data-adsslot="ET_Home/ET_Home_Home/ET_HP_Skin_LHS_125" data-fallback="1" data-loc="All" data-size="[[160, 600], [125, 600],[120,600]]" id="skinningleft_backup"></div><div class="no_onetaplogin hidden"></div><main class="pageHolder 268"><div class="primeDW" id="topAd" l1="0" l2="0" l3="0" lan=""><section id="topAd" testpage="0" vw_campaign="0"><div data-adsslot="ET_Home/ET_Home_Home/ET_HP_ATF_728" data-loc="All" data-oop="0" data-size="[[1003, 90],[970,90],[728, 90]]" id="div-gpt-ad-1590585873929-0"></div></section></div><div class="band"><div class="contentwrapper bandCont clearfix"><div class="flipWrapper" style="float: left;"><div class="mkt_indices_band clearfix"><div class="band-items band-item-sm" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/indices/nifty_50_companies" target="_blank">
marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div></div></div></div><!--/market_topband_new.cms?default_tv=0&visualrevenue=HP&tracking=ETHome-IndicesBand&default_tv_popup=0&band_ad_active=0&keepadfirst=1potime:3--><header class="header clearfix default"><div class="dtc vam logoPart tac"><a class="hp_logo" href="/" title="The Economic Times"><img alt="The Economic Times" fetchpriority="fetchpriority" height="51" src="data:image/png;base64,..." width="464"/></a><div class="timeEdition tac"><div class="dib prel edition"><span>English Edition</span><span class="edMenu"><span class="ed">English Edition</span><a class="edHin" data-ga-onclick="Web Top Nav Edition#Hindi#url" href="https://hindi.economictimes.com/" rel="noopener dofollow" target="_blank">हिन्दी</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#gujarati#url" href="https://gujarati.economictimes.com/" rel="noopener dofollow" target="_blank">ગુજરાતી</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#marathi#url" href="https://marathi.economictimes.com/" rel="noopener dofollow" target="_blank">मराठी</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#bengali#url" href="https://bengali.economictimes.com/" rel="noopener dofollow" target="_blank">বাংলা</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#kannada#url" href="https://kannada.economictimes.com/" rel="noopener dofollow" target="_blank">ಕನ್ನಡ</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#malayalam#url" href="https://malayalam.economictimes.com/" rel="noopener dofollow" target="_blank">മലയാളം</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#tamil#url" href="https://tamil.economictimes.com/" rel="noopener dofollow" target="_blank">தமிழ்</a><a class="edHin" data-ga-onclick="Web Top Nav Edition#telugu#url" href="https://telugu.economictimes.com/" rel="noopener dofollow" target="_blank">తెలుగు</a></span></div><span data-dt="2023-02-25 15:25:01.105"><span> | </span><span class="dib time">25 February, 2023, 03:25 PM IST</span></span><span> | </span><a class="dib epaper" data-ga-onclick="Web Top Nav Epaper link#Click on Epaper link#url" href="/printhome.cms" rel="nofollow" target="_blank">Today's Paper</a></div><div class="flr subSign"><a class="dib subScribe" data-ga-onclick="Subscription Flow#SYFT#ATF - url" href="/plans.cms">Subscribe</a><div class="dib signInOut prel signIn"><a class="signInLink" data-ga-onclick="ET Login#Signin - Sign In - Click#ATF - url" href="javascript:objUser.login()">Sign In</a></div><div class="soWrapper"><a class="hdr_spcl_ofr top_f_us" data-ga-onclick="Subscription Flow#SYFT#HomepageOfferHeader" data-url="https://economictimes.indiatimes.com/plans.cms"><prime_campaign>Special Offer on ETPrime</prime_campaign></a><!--/prime_campaign.cms?msid=81429572&bannertype=toppotime:2--></div></div></div></header><div class="srch-container prel"><div class="srch-overlay-div" id="topSearch"><div class="srch-overlay-content"><input autocomplete="off" class="inputBox" data-search-input="" name="ticker_newsearch" placeholder="Search News, Stock Quotes &amp; NAV" type="text" value=""/><div class="srch-btn btn">Search</div><div class="srch-close">+</div></div></div></div><div class="navFixRef"></div><div class="nav_block clr" id="topnavBlk"><nav class="level1 contentwrapper" data-ga-category="EThome-TopNav" id="topnav" itemscope="itemscope" itemtype="https://www.schema.org/SiteNavigationElement" nav-sec1=""><div class="sections" id="sideMenu"><span class="menuIcon cSprite"></span><nav class="ddNav" id="sideBarNav"></nav></div><div><a class="current" href="/" itemprop="url"><meta content="Home" itemprop="name"/>Home</a></div><div data-ga-action="ETPrime"><a class ...
#                         Read Today's Paper
# 		            </a></div></div></div><!--/printedition_discoverybanner.cms?tmp=defaultpotime:2--><div class="subheader_wrapper hide"><div class="header_wrapper"><div class="flt"><h5>Read. Lead. Succeed. ET Prime - For Members Only</h5><ul><li>Sharp Insight-rich, Indepth stories across 20+ sectors</li><li>Access the exclusive Economic Times stories, Editorial and Expert opinion</li></ul></div><div class="flr btn_wrapper"><a class="btn uc" data-ga-onclick="Subscription Flow#SYFT#Prime Home Header" id="pricePlan">START YOUR MEMBERSHIP</a></div></div></div><!--/primehome_header.cmspotime:3--><div id="emeritusHeader"></div><div class="clr"></div><style>
# 	        #wa_banner{padding: 12px 61px 7px 13px;box-shadow: 0 4px 6px 0 rgba(0, 0, 0, 0.1);background-image: linear-gradient(to left, #fee9e2 0%, rgba(255, 255, 255, 0.5)), linear-gradient(to bottom, #fff, #fff);}
# 	        #wa_banner > div{display:inline-block;vertical-align:middle}
# 	        #wa_banner h3{font-size:18px}
# 	        #wa_banner p{font-weight:500;line-height:1.25;margin-top: 2px;}
# 	        #wa_banner .subsBtn{padding: 8px 28px 8px 30px;border-radius: 2px;background-color: #e81e3d;font-weight:700;font-size:13px;margin-top: 5px;}
# 	        #wa_banner .subsBtn a{color:#FFF;text-decoration: none;}
# 	    </style><div class="hide" id="wa_banner"><div><img height="41" src="/photo/90287383.cms" style="margin-right:15px" width="40"/></div><div><h3>Be the first one to get exclusive stories!</h3><p>Get only relevant updates on WhatsApp. No Spam.</p></div><div class="subsBtn uc flr"><a data-ga-onclick="WhatsApp_Engagement#Web#banner_click" href="/whatsappalert.cms">Join Us On WhatsApp</a></div></div><!--/home_whatsappbanner.cms?pagetype=defaultpotime:2--><style>
# 	        #stk_bnr,#TP_bnr {width:100%;box-shadow: 0 4px 6px 0 rgba(0, 0, 0, 0.1);text-align: center;}
# 	        #stk_bnr > a,#TP_bnr > a{display:block;cursor: pointer;text-decoration: none;}
# 	        #stk_bnr .bnr_wrapper,#TP_bnr .bnr_wrapper{padding: 12px;font-family: Montserrat;display: flex;align-items: center;width:1003px;margin:0 auto;box-sizing:border-box}
# 	        #TP_bnr .bnr_wrapper{padding: 12px 10px}
# 	        #stk_bnr .dtls{width:75%}
# 	        #TP_bnr .dtls{width:75%}
# 	        #stk_bnr .dtls .dtls_head span,#TP_bnr .dtls .dtls_head span{border-radius: 3px 0 0 3px;background-image: linear-gradient(to bottom, #f54070, #e81e3d);font-size:12px;font-weight:bold;padding: 2px 12px 3px 9px;color: #fff;position: relative;}
# 	        #TP_bnr .dtls .dtls_head span{font-size:9.6px;padding: 4px 12px 3px 7px;}
# 	        #stk_bnr .dtls .dtls_head span:after,#TP_bnr .dtls .dtls_head span:after{content: "";position: absolute;right: 0px;bottom: 0;width: 0px;height: 0px;border-bottom: 10px solid #fff;border-top: 10px solid #fff;border-left: 10px solid transparent;}
# 	        #TP_bnr .dtls .dtls_head span:after{border-bottom: 9px solid #fff;border-top: 9px solid #fff;border-left: 9px solid transparent;}
# 	        #stk_bnr .dtls .dtls_head h2,#TP_bnr .dtls .dtls_head h2{font-family: Faustina;font-size: 24px;font-weight: 600;display: inline;vertical-align: middle;line-height: 23px;margin-left: 8px;}
# 	        #TP_bnr .dtls .dtls_head h2{font-family: Faustina;font-size: 24px;font-weight: 600;display: inline;margin-left: 8px;}
# 	        #stk_bnr .dtls .dtls_bullets,#TP_bnr .dtls .dtls_bullets{margin-top: 6px;}
# 	        #stk_bnr .dtls .dtls_bullets li,#TP_bnr .dtls .dtls_bullets li {font-size: 14px;font-weight: 400;line-height: 1.25;display: inline-block;margin-right: 20px;list-style: none;}
# 	        #TP_bnr .dtls .dtls_bullets li{margin-right: 27px}
# 	        #stk_bnr .dtls .dtls_bullets li:last-child,#TP_bnr .dtls .dtls_bullets li:last-child {margin-right: 0;}
# 	        #stk_bnr .dtls .dtls_bullets li:before,#TP_bnr .dtls .dtls_bullets li:before {width: 2px;display: inline-block;vertical-align: middle;margin: 0 5px 2px 0;}
# 	        #stk_bnr .stock_page_btn,#TP_bnr .stock_page_btn{color: #da2337;font-size:14px;font-weight:600;padding: 8px 14px;display: block;border-radius: 2px;border: solid 1px #da2337;text-align: left;}
# 	        #TP_bnr .stock_page_btn{padding: 8px 12px;}
# 	        .dtls_head h2 img{margin: 0 2px 1px 5px;vertical-align: sub;}
#
# 	        #stk_bnr a:hover .stock_page_btn, #TP_bnr a:hover .stock_page_btn{background-color:#da2337;color:#FFF}
# 	    </style><div class="hide" id="stk_bnr"><a data-ga-onclick="ePaper_discovery#Homepage_Band_Paid_User#HomePage Print Ediion Header" href="/print_edition.cms" target="_blank"><div class="bnr_wrapper"><div class="dtls"><div class="dtls_head"><h2>Introducing <img alt="Print Edition" class="lazy" data-original="https://img.etimg.com/photo/91621060.cms" height="28" src="https://img.etimg.com/photo/42031747.cms" width="175"/> Exclusively For Prime Members</h2></div><div class="dtls_bullets"><li>Experience your Economic Times newspaper, the digital way.</li></div></div><div class="stock_page_btn">Read Today's Print Edition</div></div></a></div><div class="hide" id="TP_bnr"><a class="bnr_click" href="/print_edition.cms" target="_blank"><div class="bnr_wrapper"><div class="dtls"><div class="dtls_head"><h2>Introducing <img alt="Print Edition" class="lazy" data-original="https://img.etimg.com/photo/91621060.cms" height="28" src="https://img.etimg.com/photo/42031747.cms" width="175"/> Exclusively For Prime Members</h2></div><div class="dtls_bullets"><li>Experience your Economic Times newspaper, the digital way.</li></div></div><div class="stock_page_btn">Read Today's Print Edition</div></div></a></div><!--/home_stockbanner.cms?pagetype=defaultpotime:6--><div class="clr"></div><section class="clearfix main_container" data-ga-category="HP Clicks"><section id="pageContent"><section class="latestStry clearfix"><div class="topStories lftBlk flt" data-ga-action="Top Stories" id="topStories" itemscope="itemscope" itemtype="https://schema.org/ItemList"><ul class="newsList flt w-100"><li class="clearfix font_faus" itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><h1><meta content="1" itemprop="position"/><span data-ga-onclick="1 - href" href="/jobs/mid-career/ev-industry-in-india-battles-high-attrition-amid-demand-for-talent/articleshow/98218408.cms" itemprop="url" target="_blank"><meta content="Talent wars are threatening to upend India's electric ride" itemprop="name"/><img alt="Talent wars are threatening to upend India's electric ride" class="latestTopstry flt" height="75" src="https://img.etimg.com/thumb/msid-98218408,width-120,imgsize-10426,resizemode-4/talent-wars-are-threatening-to-upend-indias-electric-ride.jpg" width="100"/></span><a data-ga-onclick="1 - href" href="/jobs/mid-career/ev-industry-in-india-battles-high-attrition-amid-demand-for-talent/articleshow/98218408.cms" itemprop="url" target="_blank">Talent wars are threatening to upend India's electric ride</a></h1></li><li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><meta content="2" itemprop="position"/><span data-ga-onclick="2 - href" href="/news/economy/indicators/extreme-heat-is-coming-know-the-different-ways-it-can-harm-indias-economy/articleshow/98229841.cms" itemprop="url" target="_blank"><meta content="Extreme heat and the risks it poses for India" itemprop="name"/></span><a data-ga-onclick="2 - href" href="/news/economy/indicators/extreme-heat-is-coming-know-the-different-ways-it-can-harm-indias-economy/articleshow/98229841.cms" itemprop="url" target="_blank">Extreme heat and the risks it poses for India</a></li><li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><meta content="3" itemprop="position"/><span data-ga-onclick="3 - href" href="/markets/stocks/news/fears-of-loss-in-adani-group-portfolio-sends-lic-near-all-time-low/articleshow/98226128.cms" itemprop="url" target="_blank"><meta content="Adani fears send LIC near all-time low" itemprop="name"/></span><a data-ga-onclick="3 - href" href="/markets/stocks/news/fears-of-loss-in-adani-group-portfolio-sends-lic-near-all-time-low/articleshow/98226128.cms" itemprop="url" target="_blank">Adani fears send LIC near all-time low</a></li><li itemprop="itemListElement" itemscope="itemscope" itemtype="https://schema.org/ListItem"><meta content="4" itemprop="position"/><span data-ga-onclick="4 - href" href= ...
#                     </span></div><div class="wcol"><a class="wrapLines l1" href="/markets/cryptocurrency/ethereum-price/cryptodetail/symbol-eth.cms" onclick="ga('send', 'event', 'HP Data Band', 'eth - click', '')" target="_blank">Ethereum Price</a><span class="fw_600">₹ 1,33,078</span><span class="down"><i class="crypto_sprite1"></i>-2.73%
#                     </span></div><div class="wcol"><a class="wrapLines l1" href="/markets/cryptocurrency/tether-price/cryptodetail/symbol-usdt.cms" onclick="ga('send', 'event', 'HP Data Band', 'usdt - click', '')" target="_blank">Tether Price</a><span class="fw_600">₹ 83.07</span><span class="up"><i class="crypto_sprite1"></i>0.39%
#                     </span></div><div class="wcol"><a class="wrapLines l1" href="/markets/cryptocurrency/bnb-price/cryptodetail/symbol-bnb.cms" onclick="ga('send', 'event', 'HP Data Band', 'bnb - click', '')" target="_blank">BNB Price</a><span class="fw_600">₹ 25,000</span><span class="down"><i class="crypto_sprite1"></i>-2.95%
#                     </span></div></div><div class="moreNews flr"><a data-ga-onclick="More - href" href="/markets/cryptocurrency" target="_blank">Cryptocurrency</a> »</div><!--/home_cryptocurrency_news.cms?msid=82519373potime:7--></section><div class="currencyConverter clearfix"><a href="/markets/forex/currency-converter" target="_blank"><span class="converterImg hpSprite flt"></span></a><form action="/currency_converter.cms" class="flr" method="get" name="forexConverter" onsubmit="return objHome.validateConverter();"><div class="boldText">Rs</div><div class="currency"><input id="amount" name="amount" type="text" value="100"/></div><div class="boldText">To</div><div class="convert"><select class="textboxsubsN" id="tocur" name="tocur"><option selected="true" value="USD">US Dollar</option><option value="CAD">CAN Dollar</option><option value="CNY">Chinese Yuan</option><option value="EUR">Euro</option><option value="HKD">HK Dollar</option><option value="IDR">Indonesian Rupiah</option><option value="JPY">Japanese Yen</option><option value
#             .amazon_widget .categList figure{height:115px;margin:0 auto;border:1px solid #e4e4e4;position:relative}
#             .amazon_widget ul.categList li:hover figure{box-shadow: 0 4px 10px 0 rgba(0, 0, 0, 0.1);}
#             .amazon_widget .categList figure > img {width: auto;height: auto;position: absolute;top: 0;left: 0;bottom: 0;right: 0;max-width: 100%;max-height: 100%;display: block;margin: 0px auto;}
#             .amazon_widget .categList .deal{font-size:10px;padding: 0 4px 0 5px;box-shadow: 0 1px 4px 0 var(--black-10);background-color: #fff30f;margin:8px 0 5px 0;font-weight:700;display: inline-block;}
#             .amazon_widget .categList h3{font-weight: 500;}
#             .amazon_widget .categList .off{font-size:10px;z-index:1;position:absolute;top:10px;left:10px;color:#fff;font-weight:700;width: 125px;height:17px;text-align: left;}
#             .amazon_widget .categList figure span>img {z-index: -1;left: -10px;position: relative;width: 102px;height: 17px;top: -15px;}
#             .amazon_widget .nextprev-btn {top: 49%;position: absolute;width: 100%;}
#             .amazon_widget .nextprev-btn .btn {width: 26px;height: 25px;position: relative;z-index: 11;background-size: 312px;cursor: pointer;}
#             .amazon_widget .nextprev-btn .btn.prev-btn {background-position: -212px -2px;left: -13px;}
#             .amazon_widget .nextprev-btn .btn.next-btn {background-position: -241px -2px;right: -11px;}
#             .amazon_widget .nextprev-btn .btn.disable{opacity:0.5;cursor: not-allowed;}
#             .amazon_widget .moreNews{maqrgin-top:15px}
#
#                 .amazon_widget ul.categList li{text-align:left}
#                 .amazon_widget .categList figure{height:116px;border:none}
#                 .amazon_widget .categList h3{font-size:14px;font-family: 'Faustina', sans-serif;}
#             </style><div class="secWidget clearfix amazon_widget" data-ga-category="ET_HP_WEB"><h2 class="heading"><a href="/top-trending-products" target="_blank">Top Trending Products</a></h2><div class="overh"><div class="amazonSlider" data-ga-action="CategoryWidget_Click"><ul class="categList"><li><a data-ga-onclick="_1" href="/top-trending-products/major-appliances/air-conditioners/10-best-2-ton-split-air-conditioners-suitable-for-large-rooms/articleshow/97867722.cms" rel="sponsored nofollow" target="_blank"><figure><img alt="10 Best 2-Ton Split Air Conditioners Suitable for Large Rooms" data-original="https://img.etimg.com/photo/msid-97867722,imgsize-6444/10-best-2-ton-split-air-conditioners-suitable-for-large-rooms.jpg" src="https://img.etimg.com/photo/42031747.cms" title="10 Best 2-Ton Split Air Conditioners Suitable for Large Rooms"/></figure><h3>10 Best 2-Ton Split Air Conditioners Suitable for Large Rooms</h3></a></li><li><a data-ga-onclick="_2" href="/top-trending-products/major-appliances/air-conditioners/10-best-window-air-conditioners-for-this-summer-season/articleshow/97952822.cms" rel="sponsored nofollow" target="_blank"><figure><img alt="10 Best Window Air Conditioners for this Summer Season" data-original="https://img.etimg.com/photo/msid-97952822,imgsize-22660/10-best-window-air-conditioners-for-this-summer-season.jpg" src="https://img.etimg.com/photo/42031747.cms" title="10 Best Window Air Conditioners for this Summer Season"/></figure><h3>10 Best Window Air Conditioners for this Summer Season</h3></a></li><li><a data-ga-onclick="_3" href="/top-trending-products/major-appliances/air-conditioners/5-best-1-5-ton-acs-choose-from-windows-and-split-air-conditioners/articleshow/97919765.cms" rel="sponsored nofollow" target="_blank"><figure><img alt
-tn-cm/articleshow/98229619.cms" target="_blank">Rs 1,000 monthly assistance for women to be implemented, says TN CM</a></div><div class="stryList clearfix"><a data-ga-onclick="5 - href" href="/news/politics-and-nation/apne-baap-ka-samman-nahi-kar-paye-ho-yogi-lashes-out-at-akhilesh-in-up-assembly/articleshow/98228420.cms" target="_blank">"Apne baap ka samman nahi kar paye ho": Yogi Adityanath lashes out at Akhilesh in UP Assembly</a></div></div><div class="clr"></div><div class="moreNews flr"><a data-ga-onclick="More - href" href="/news/politics-nation" target="_blank">Politics</a> »</div></section><!--/home_otherwidget.cms?msid=1052732854&widget=politics&head=Politics&sidestry=true&link=/news/politics-nation&imageStry=2&noOfStry=5potime:37--></div><section class="clearfix"><div class="seoWidget" data-ga-action="Top Trending Terms Seo Widget" id="seoWrapper_rhs"><div class="prel"><div class="head">Top Trending Terms: </div><div class="nextprev-btn slider_embd"><div class="prev-btn arw_blk disable flt" data-ga-onclick="Previous | href"><span class="alft"></span></div><div class="ts-dots flt"><ul></ul></div><div class="next-btn arw_blk ryt flt" ...
#
#     		            if(typeof sessionStorage != 'undefined') {
#                             if(sessionStorage.getItem('stk_ftr_ad_rm')){
#                                 _log("stk_ftr_ad removed");
#                                 document.querySelectorAll(".stk_ftr_ad")[0].remove();
#                             }
#                             if(sessionStorage.getItem('stk_ftr_ad_exin_rm')){
#                                 _log("stk_ftr_ad_exin removed");
#                                 document.querySelectorAll(".stk_ftr_ad_exin")[0].remove();
#                             }
#                         }
#
# 		        </script><span class="hidden livetv_popup"></span><script src="https://js.etimg.com/d/js_jquery_cdn/v-1.cms" type="text/javascript"></script><script src="https://js.etimg.com/d/js_scripts_cdn/v-1.cms" type="text/javascript"></script><script>var language = '';</script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_common_new/v-533,minify-1.cms" type="text/javascript"></script><script defer="" onerror="errorLogs(this)" src="https://js.etimg.com/d/js_etidentifierv/v-23,minify-1.cms" type="text/javascript"></script><script defer="" onerror="errorLogs(this)" src="https://js.etimg.com/d/js_socialdatacapture_min/v-131,minify-1.cms" type="text/javascript"></script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/js_default_new2/v-72,minify-1.cms" type="text/javascript"></script><script>
#
# 				    var logAPIResponse = 1;
# 				$(document).ready(function () {
#                     var artCnt = customDimension.dimension94;
#                     if(objGdpr.allow() && artCnt && artCnt >= 3) {
#                         loadModule({'module_name': 'js_recommendation', v: 83, ref:'hpRecommendation'});
#                     }
#                     window.loadScript && loadScript('https://sf-objects-s3.tilc.in/sf-objects/cdnperf.js');
#                     var $jS = $.jStorage; if($jS.get('c_oneTapLogin') && $jS.getTTL('c_oneTapLogin') == 0) {$jS.deleteKey('c_oneTapLogin')}
#                 })
#
#                 </script><script>
# 	         if($('.main_container').length == 0) {
# 	            saveLogs({'type': 'main_container', 'container': 'missing'});
# ...
#                 if (document.cookie.indexOf(disableStr + '=true') > -1) { window[disableStr + '-' + gaProperty] = true; }
#
#                 ga('set', 'anonymizeIp', true);
#                 ga('create', gaProperty, 'auto', {'allowLinker': true});
#                 ga('require', 'linker');
#                 ga('linker:autoLink', ['economictimes.com']);
#                 ga('require', 'displayfeatures');
#                 try {
#                     var et_ua = window.navigator && navigator.userAgent.toLowerCase() || '';
#                     if(et_ua.indexOf('bot') == -1 && et_ua.indexOf('lighthouse') == -1 && et_ua.indexOf('ptst/') == -1 && et_ua.indexOf('speed insights') == -1) {
#                         window.optimizely = window.optimizely || [];
#                         window.optimizely.push("activateUniversalAnalytics");
#                         ga('require', 'GTM-WV452H7');
#                     }
#                 } catch (e) {}
#
#                 (function () {
#                     setDim(25,"default");
#                     setDim(26,"Home");
#                     setDim(27,"Home");
#                     setDim(29,"0");
#                     setDim(48,"2160010");
#                     setDim(30,window._col_uuid);setDim(57,window.__tiluuid);
#
#
#                     if(window.geolocation) {setDim(109, window.geolocation == 1 ? 'IND' : 'INTER');}
#                     var a = window.localStorage && localStorage.getItem('et_syftCounter') || '';
#                     a = a && JSON.parse(a) || {};
#                     if(a.beforeSyft) {setDim(32,a.beforeSyft);}
#                     if(a.afterSyft) {setDim(33,a.afterSyft);}
#                 })()
#
#
#
# 	    var trafficSource = '';
# 	    function getjStorageVal(keyName) { var jString = localStorage.getItem("jStorage"), value = ''; try { if(jString) { var objJstorage = JSON.parse(jString); value = objJstorage[keyName] ? objJstorage[keyName] : ''; } } catch (e) {} return value; }
# 		(function () {
# 		    function addZero(num) {return (num >= 0 && num < 10) ? '0' + num : num;}
# 		    try {
#     		    lastClick = getjStorageVal('etu_last_click');
#                 if(!lastClick) {
#                     lastClick = document.referrer.indexOf('indiatimes.com') == -1 ? 'direct_landing_articleshow' : 'other';
#                 }
#                 var dref = document.referrer, wlh = window.location.href.toLowerCase(), wlp = window.location.pathname;
#                 if(/google|bing|yahoo/ig.test(dref)) {trafficSource = 'organic';}
#                 else if(/facebook|linkedin|instagram|twitter/ig.test(dref) || wlh.indexOf('utm_medium=social') != -1) { trafficSource = 'social';}
#                 else if(wlh.indexOf('utm_medium=email') != -1) {trafficSource = 'newsletter'; }
#                 else if(wlh.indexOf('utm_source=etnotifications') != -1) {trafficSource = 'notifications'; }
#                 else if(getjStorageVal('etu_source')) { trafficSource = getjStorageVal('etu_source');}
#
#                 if(!trafficSource) {
#                     if(wlp == '/' || wlp == '/default.cms') {trafficSource = 'direct'}
#                     else if(wlp.indexOf('articleshow')) {trafficSource = 'organic'}
#                     else {trafficSource = 'other'}
#                 }
#
#                 var dtObject = new Date(), dt = (dtObject.getFullYear() + '' + addZero(dtObject.getMonth() + 1) + '' + addZero(dtObject.getDate())), key = 'et_article_' + dt;
#                 var articleReadCountToday = (getjStorageVal(key) || []).length;
#                 var articleReadCountMonth = 0;
#                 var paidArticleReadCountMonth = 0;
#                 var jString = localStorage.getItem("jStorage");
#                 try {
#                     if(jString) {
#                         var objJstorage = JSON.parse(jString);
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_article_') != -1}).forEach(function (key) { articleReadCountMonth += getjStorageVal(key).length});
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_primearticle_') != -1}).forEach(function (key) { paidArticleReadCountMonth += getjStorageVal(key) || 0});
#                     }
# 	            } catch (e) {}
#
#                 var paidArticleReadCountTodayKey = 'et_primearticle_' + dt;
#                 var paidArticleReadCountToday = getjStorageVal(paidArticleReadCountTodayKey) || 0;
#                 var continuousPaywallList = getjStorageVal('et_continuousPaywalled') || [];
#
#
#                 setDim(92, lastClick);
#                 setDim(93, trafficSource);
#                 setDim(94, articleReadCountToday);
#                 setDim(95, articleReadCountMonth);
#                 setDim(96, continuousPaywallList.length);
#                 setDim(97, paidArticleReadCountMonth);
#                 setDim(98, paidArticleReadCountToday);
#
#                 var subsStatus = '-', d3 = 'NONLOGGEDIN';
#                 var jData = JSON.parse(localStorage.getItem('jStorage'));
#                 var b = document.getElementsByTagName('html')[0];
#                 if(ssoid = getCookie('ssoid')) {
#                     try {
#                         d3 = 'LOGGEDIN';
#                         var grx_userData = jData && jData['prime_'+getCookie('TicketId')] || {};
#                         grx_userData = grx_userData || {};
#                         var grx_up = grx_userData.permissions || [];
#                         if(grx_up.indexOf("expired_subscription") > -1) {
#                             subsStatus = 'Expired User';
#         		        } else if (grx_up.indexOf("subscribed") > -1 && grx_up.indexOf("cancelled_subscription") > -1 && grx_up.indexOf("can_buy_subscription") > -1) {
#         		            subsStatus = 'Paid User - In Trial';
#         		            b.classList.add("cancelled_user");
#         		        } else if(grx_up.indexOf("subscribed") > -1) {
#         		            subsStatus = 'Paid User';
#                             b.classList.add("prime_user");
#         		        } else if(grx_up.indexOf("etadfree_subscribed") > -1) {
#         		            subsStatus = 'Ad Free User';
#         		        } else if (grx_up.length == 0) {
#         		            subsStatus = 'Permission Missing';
#         		        } else {
#         		            subsStatus = 'Free User';
#         		        }
#
#         		        if(grx_up.indexOf("subscribed") > -1) {
#         		            b.classList.add("prime_header");
#         		        }
#     		        } catch (e) {}
#                 } else {
#                     subsStatus = 'Free User';
#                 }
#
#                 if(subsStatus == '-' || subsStatus == '' || subsStatus == 'Expired User' || subsStatus == 'Free User') {
#                     b.classList.add("free_user");
#                 }
#                 setDim(3, d3); setDim(10, d3); setDim(37, subsStatus);
#
# 		    } catch (e) {}
# 		})();
#
#
# 	    setDim(1,'homepage');setDim(24,'homepage');
#
#                 ga('send', 'pageview', customDimension);
#
#
#     		    var newHookId ='0';
#
#         			var subsec1_value ='0', subsec1_2value = '0';
#
#     			        if(subsec1_value == '1715249553' && subsec1_2value == '1052732854'){
#     			            subsec1_value = '1052732854'; // politicsnation
#     			        }else if(subsec1_value == '1715249553' && subsec1_2value == '1373380680'){
#     			            subsec1_value = '1373380680'; // Economy
#     			        }
#
#
#
#         (function (g, r, o, w, t, h, rx) {
#             g[t] = g[t] || function () {(g[t].q = g[t].q || []).push(arguments)
#             }, g[t].l = 1 * new Date();
#             g[t] = g[t] || {}, h = r.createElement(o), rx = r.getElementsByTagName(o)[0];
#             h.async = 1;h.src = w;rx.parentNode.insertBefore(h, rx)
#         })(window, document, 'script', 'https://static.growthrx.in/js/v2/web-sdk.js', 'grx');
#         grx('init', 'gf999c70d');
#         var grxDimension = {url: window.location.href, title : document.title, referral_url : document.referrer, platform: 'desktop'};
#         var pfuuid = getCookie('pfuuid');
#         if(pfuuid) { grxDimension['et_uuid'] = pfuuid}
#
#         grx('config',"service_worker","/et_serviceworker.cms");
#         grx('config',"applicationServerKey","BIEYq99VozBXu5wtCtElr19cYzEZCgSZAYV5amfqzU1IWrR8SWr5T0Htp72bVbslw08rhMJvkrRFT_11HS8zz5c");
#         var isSafari = /^((?!chrome|android).)*safari/i.test(navigator.userAgent);
#         var isPlanPage = "false";
#         var isLoginPage = "false";
#
#         if(isPlanPage === "false" && isLoginPage === "false" && !isSafari) {
#             grx('enableCustompopup');
#         }
#
#
#
#             (function () {
#                 grx('userId', getCookie('ssoid') || '-');
#                 try {
#                     if(window.localStorage && localStorage.getItem) {
#                         var jString = localStorage.getItem("jStorage");
#                         if(jString) {
#                             var objJstorage = JSON.parse(jString), objProf = objJstorage['et_subscription_profile'], userInfo = objJstorage['userInfo'] || {}, peuuid = getCookie('peuuid'), pfuuid = getCookie('pfuuid');
#                             for (var attrname in objProf) { grxDimension[attrname] = objProf[attrname]; };
#                             var dt = new Date(), tDate = dt.getDate()+'-'+(dt.getMonth()+1)+'-'+dt.getFullYear(),loggedIn = (getCookie('ssoid') ? 'Y' : 'N');
#                             grxDimension['first_date_on_et'] = objJstorage['et_first_date'] || tDate;
#                             grxDimension['last_visited_date'] = tDate;
#                             grxDimension['logged_in'] = userInfo['email'] ? 'Y' : 'N';
#                             grxDimension['email'] = userInfo['email'] || '-';
#                             grxDimension['first_name'] = userInfo['fname'] || '-';
#                             grxDimension['last_name'] = userInfo['lname'] || '-';
#                             grxDimension['current_subscriber_status'] = customDimension.dimension37 || '-';
#                             if(peuuid) {grxDimension['web_peuuid'] = peuuid;}
#                             if(pfuuid) {grxDimension['web_pfuuid'] = pfuuid;}
#                         }
#                     }
#                     if(window.customDimension && window.objDim) {
#                         for(key in customDimension) {
#                             var dimId = 'd' + key.substr(9, key.length);
#                             if(objDim[dimId] && typeof customDimension[key] != 'undefined') { grxDimension[objDim[dimId]] = customDimension[key]; }
#                         }
#                     }
#                 }catch(e) {
#                     console.log('Error profile Dimension');
#                 }
#             })()
#
#         grx('track', 'page_view', grxDimension);
#
#             var _comscore = _comscore || [];
#             _comscore.push({ c1: "2", c2: "6036484"});
#
#             if(window.allowGdpr == 1) {
#                 (function() {
#                     var s = document.createElement('script'), el = document.getElementsByTagName("script")[0]; s.async = true;
#                     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#                     el.parentNode.insertBefore(s, el);
#                 })();
#             }
#
#
#
#                 if(window.allowGdpr == 1) {
#                     (function() {
#             			function pingIbeat() {
#                 			window._pg_endpt=(new Date()).getTime();
#                 			var e = document.createElement('script');
#                 			e.setAttribute('language', 'javascript');
#                 			e.setAttribute('type', 'text/javascript');
#                 			e.setAttribute('async', true);
#                 			var dt = window.dateFormat ? dateFormat(new Date(), '%Y%M%d') : 1;
#                 			var sd = window.objDomain && objDomain.js || '';
#                 			e.setAttribute('src', sd + '/js_ibeat_ext.cms?ver=9&v=' + dt);
#                 			if((window.location.href.indexOf('etdev8'))>-1 || (window.location.href.indexOf('etstg'))>-1) {
#                 			    e.setAttribute('src', "https://agi-static.indiatimes.com/cms-common/stg/stg-ibeat.min.js");
#                 			}
#                 			document.head.appendChild(e);
#             			}
#             			if(typeof window.addEventListener == 'function') {
#             			    window.addEventListener("load", pingIbeat, false);
#             			} else {
#                 			var oldonload = window.onload;
#                 			window.onload = (typeof window.onload != 'function') ?
#                 			pingIbeat : function() { oldonload(); pingIbeat(); };
#             			}
#             		})();
#                 }
#
#
#         }
# 	    </script><script type="application/ld+json">
#         	    {
#         	        "@context" : "https://schema.org",
#         		  	"@type": "NewsMediaOrganization",
#         		  	"name": "Economic Times",
#         		    "url" : "https://economictimes.indiatimes.com/","sameAs" : [ "https://www.facebook.com/EconomicTimes","https://twitter.com/economictimes","https://plus.google.com/+TheEconomicTimes"],
#         		    "logo": {
#         		      "@type": "ImageObject",
#             	      "url": "https://img.etimg.com/thumb/msid-76939477,width-600,height-60,quality-100/economictimes.jpg",
#         		      "width": 600,
#         		      "height": 60
#         		    }
#         		  }
#             </script><script>
# 				    var subsec1_value = '';
# 				    var skinningExist=false;
# 				        /*ints = '1', // 0 -> inactive, 1 -> active
# 				        intsCountryChk = 1, // 1 -> if target to specific location, 0 -> no location
# 				        intsAllowedCountry = [1], // please mark ids without quote e.g [2,3,4]
# 				        intsFequencyCap = 3,
# 				        intsPath = '/defaultinterstitial.cms';*/
# 				        // intsPath = '/configspace/etmain_static/content/defaultinterstitial.html';
#
#
#         				function getQueryParams(qs) {
#         			        qs = qs.split('+').join(' ');
#         			        var params = {},
#         			            tokens,
#         			            re = /[?&]?([^=]+)=([^&]*)/g;
#         			        while (tokens = re.exec(qs)) {
#         			            params[decodeURIComponent(tokens[1])] = decodeURIComponent(tokens[2]);
#         			        }
#         			        return params;
#     			        }
#         			    /*var query = getQueryParams(document.location.search);
#
#     				    ints = query.ints ? query.ints : ints;*/
#                      	// var homePageRedirectTo = '/budget';
#
# 				</script><script onerror="errorLogs(this)" src="https://js.etimg.com/d/jshome_topnew/v-58,minify-1.cms" type="text/javascript"></script><style>
#                     .livetv_cont{position:relative;}
#                     .livetv_layer{position:absolute;width: 152px; height: 114px;z-index:1;cursor:pointer;}
#                     .free_user #topStories [data-p='24'] h2 a{font-size: 14px;font-weight:500;}
#                     .free_user #topStories [data-p='24'] img.smallImg{display:none;}
#                     .mainLead{text-align:center;margin:0 0 30px 0}
#                     .mainLead .main a{font-size:32px;color:#000;font-weight: 700;margin-bottom: 10px;font-family:'Faustina',sans-serif;}
#                     .prime_user .iframeyt{display:none;}
#                     .main_container a:visited:not(.skip_vcolor):not(h2 a):not(h4 a):not(.head a):not(.top_mf_wdgt a):not(#sportlight_mf a):not(.moreNews a):not(.Ntxt a), .newsByInd h4 a:visited { color: #636363; }
#                     /*header.header {background-image: url(https://img.etimg.com/photo/94940834.cms);margin: 0 auto;box-sizing: border-box;display: table;width: 1003px;position: relative;padding: 7px 0;z-index: 2;min-height: 110px;background-size:1000px;}*/
#                 </style></head>

# %%
# Extract first <h1>(...)</h1> text
first_h1 = soup.select('h3')[0].text

# %%
first_h1
# Out:
# 'Be the first one to get exclusive stories!'

# %%
# Create all_h1_tags as empty list
all_h1_tags = []

# Set all_h1_tags to all h1 tags of the soup
for element in soup.select('h1'):
    all_h1_tags.append(element.text)

# Create seventh_p_text and set it to 7th p element text of the page
seventh_p_text = soup.select('p')[6].text

print(all_h1_tags, seventh_p_text)
# Out:
# ["Talent wars are threatening to upend India's electric ride"] The Home Office issued a total of 1.4 million visas last year, up from 860,000 in 2021 when coronavirus travel rules prevented movement. Work visas made up a big proportion of this, with one in three of these going to Indian workers. There also were big increases for those entering from Hong Kong and Ukraine.

# %%
# Create top_items as empty list
image_data = []

# Extract and store in top_items according to instructions on the left
images = soup.select('img')
for image in images:
    src = image.get('src')
    alt = image.get('alt')
    image_data.append({"src": src, "alt": alt})

print(image_data)
# Out:
# [{'src': 'data:image/png;base64,...', 'alt': 'The Economic Times'}, {'src': '/photo/90287383.cms', 'alt': None}, {'src': 'https://img.etimg.com/photo/42031747.cms', 'alt': 'Print Edition'}, {'src': 'https://img.etimg.com/photo/42031747.cms', 'alt': 'Print Edition'}, {'src': 'https://img.etimg.com/thumb/msid-98218408,width-120,imgsize-10426,resizemode-4/talent-wars-are-threatening-to-upend-indias-electric-ride.jpg', 'alt': "Talent wars are threatening to upend India's electric ride"}, {'src': 'https://img.etimg.com/thumb/msid-98221673,width-120,imgsize-1796962,resizemode-4/invasion-conflict-or-war-the-g20-cant-seem-to-find-the-right-word-for-putins-incursion-into-ukraine.jpg', 'alt': "Invasion, conflict or war? The G20 can't seem to find the right word for Putin's incursion into Ukraine"}, {'src': 'https://img.etimg.com/thumb/msid-98227395,width-120,imgsize-55212,resizemode-4/know-how-much-you-need-to-pay-to-get-the-higher-eps-pension-and-the-return-you-can-earn.jpg', 'alt': 'Know how much you need to pay to get the higher EPS pension, and the return you can earn'}, {'src': 'https://img.etimg.com/thumb/msid-98222348,width-120,imgsize-2539511,resizemode-4/rising-temperatures-across-india-hint-at-another-summer-squeeze-on-the-countrys-power-supply.jpg', 'alt': "Rising temperatures across India hint at another summer squeeze on the country's power supply"}, {'src': 'https://img.etimg.com/thumb/msid-98218346,width-120,imgsize-27236,resizemode-4/is-anything-fishy-about-adanis-airport-bids-the-hint-lies-in-the-long-list-of-the-ones-theyve-lost.jpg', 'alt': "Is anything fishy about Adani's airport bids? The hint lies in the long list of the ones they've lost"}, {'src': 'https://img.etimg.com/photo/msid-76930353,quality-100/et-prime-logo.jpg', 'alt': 'ET Prime'}, {'src': 'https://img.etimg.com/thumb/msid-98139340,width-100,height-75,quality-100,imgsize-101218,resizemode-4/not-india-or-vietnam-is-global-supply-chain-heading-to-mexico-canada.jpg', 'alt': 'Not India or Vietnam: Is global supply chain heading to Mexico, Canada?'}, {'src': 'https://img.etimg.com/thumb/msid-98139340,width-300,height-225,quality-100,imgsize-101218,resizemode-4/not-india-or-vietnam-is-global-supply-chain-heading-to-mexico-canada.jpg', 'alt': 'Not India or Vietnam: Is global supply chain heading to Mexico, Canada?'}, {'src': 'https://img.etimg.com/thumb/msid-98226822,width-100,height-75,quality-100,imgsize-655876,resizemode-4/this-ratio-is-better-when-looking-for-possible-wealth-creators.jpg', 'alt': 'This ratio is better when looking for possible wealth creators'}, {'src': 'https://img.etimg.com/thumb/msid-98218016,width-100,height-75,quality-100,imgsize-32464,resizemode-4/why-indian-tech-sector-may-weather-the-storm.jpg', 'alt': 'Why Indian tech sector may weather the storm'}, {'src': 'https://img.etimg.com/thumb/msid-98227691,width-100,height-75,quality-100,imgsize-43482,resizemode-4/weekly-top-picks-5-stocks-with-consistent-score-improvement-and-upside-potential-of-up-to-38.jpg', 'alt': 'Weekly Top Picks: 5 stocks with consistent score improvement and upside potential of up to 38%'}, {'src': 'https://img.etimg.com/thumb/msid-98218044,width-100,height-75,quality-100,imgsize-1977377,resizemode-4/view-with-great-age-comes-great-equanimity.jpg', 'alt': 'View: With great age comes great equanimity'}, {'src': 'https://img.etimg.com/thumb/msid-98217496,width-100,height-75,quality-100,imgsize-48232,resizemode-4/pardon-the-ai-your-honour-the-era-of-a-robot-lawyer-isnt-too-far-away.jpg', 'alt': 'Pardon the AI, Your Honour: The era of a robot lawyer isn’t too far away'}, {'src': 'https://img.etimg.com/photo/42031747.cms', 'alt': 'Gainers & Losers: Zee Entertainment among 6 stocks in limelight on Friday'}, {'src': 'https://img.etimg.com/photo/42031747.cms', 'alt': 'Tech View: Nifty forms a long bear candle. What traders should do next week'}, {'src': 'https://img.etimg.com/photo/42031747.cms', 'alt': 'Death Crossovers: These 5 stocks signal further bearishness'}, {'src ...

# %%
# Create top_items as empty list
all_links = []

# Extract and store in top_items according to instructions on the left
links = soup.select('a')
for ahref in links:
    text = ahref.text
    text = text.strip() if text is not None else ''

    href = ahref.get('href')
    href = href.strip() if href is not None else ''
    all_links.append({"href": href, "text": text})

print(all_links)
# Out:
# [{'href': 'https://economictimes.indiatimes.com/indices/nifty_50_companies', 'text': 'Benchmarks'}, {'href': 'https://economictimes.indiatimes.com/indices/nifty_50_companies', 'text': 'Nifty'}, {'href': 'https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms', 'text': 'NSE Gainer-Large Cap'}, {'href': '/gail-india-ltd/stocks/companyid-4845.cms', 'text': 'GAIL'}, {'href': 'https://mutualfund.adityabirlacapital.com/campaign/pro-investing?utm_source=economictimes&utm_medium=product_integration&utm_campaign=pro_investing', 'text': 'FEATURED FUNDSPro Investing by Aditya Birla Sun Life Mutual FundInvest Now'}, {'href': 'https://www.canararobeco.com/smart-invest/sign-in?utm_source=ET&utm_medium=InvestNowButton&utm_campaign=EquityHybridFund', 'text': 'FEATURED FUNDS★★★★★Canara Robeco Equity Hybrid Fund Direct-Growth5Y Return12.23 %\n                Invest Now'}, {'href': 'https://www.icicip